# %%
# !pip install plotly --upgrade
# Out:
# Requirement already satisfied: plotly in /opt/conda/lib/python3.11/site-packages (5.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from plotly) (23.1)

# %%
# !pip install --upgrade geopandas mapclassify folium
# !pip install census contextily adjustText
# Out:
# Requirement already satisfied: geopandas in /opt/conda/lib/python3.11/site-packages (0.14.1)
# Requirement already satisfied: mapclassify in /opt/conda/lib/python3.11/site-packages (2.6.1)
# Requirement already satisfied: folium in /opt/conda/lib/python3.11/site-packages (0.15.1)
# Requirement already satisfied: fiona>=1.8.21 in /opt/conda/lib/python3.11/site-packages (from geopandas) (1.9.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/lib/python3.11/site-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.8.0 in /opt/conda/lib/python3.11/site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: networkx>=2.7 in /opt/conda/lib/python3.11/site-packages (from mapclassify) (3.1)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.11/site-packages (from mapclassify) (1.24.4)
# Requirement already satisfied: scikit-learn>=1.0 in /opt/conda/lib/python3.11/site-packages (from mapclassify) (1.3.0)
# Requirement already satisfied: scipy>=1.8 in /opt/conda/lib/python3.11/site-packages (from mapclassify) (1.11.1)
# Requirement already satisfied: branca>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/lib/python3.11/site-packages (from folium) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /opt/conda/lib/python3.11/site-packages (from folium) (2023.7.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (2023.7.22)
# Requirement already satisfied: click~=8.0 in /opt/conda/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (8.1.6)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from scikit-learn>=1.0->mapclassify) (1.3.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn>=1.0->mapclassify) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->folium) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: census in /opt/conda/lib/python3.11/site-packages (0.8.20)
# Requirement already satisfied: contextily in /opt/conda/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: adjustText in /opt/conda/lib/python3.11/site-packages (0.8)
# Requirement already satisfied: requests>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from census) (2.31.0)
# Requirement already satisfied: geopy in /opt/conda/lib/python3.11/site-packages (from contextily) (2.3.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (from contextily) (3.7.2)
# Requirement already satisfied: mercantile in /opt/conda/lib/python3.11/site-packages (from contextily) (1.2.1)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.11/site-packages (from contextily) (10.0.0)
# Requirement already satisfied: rasterio in /opt/conda/lib/python3.11/site-packages (from contextily) (1.3.8)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.11/site-packages (from contextily) (1.3.0)
# Requirement already satisfied: xyzservices in /opt/conda/lib/python3.11/site-packages (from contextily) (2023.7.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from adjustText) (1.24.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=1.1.0->census) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=1.1.0->census) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=1.1.0->census) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=1.1.0->census) (2023.7.22)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/conda/lib/python3.11/site-packages (from geopy->contextily) (1.52)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->contextily) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib->contextily) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib->contextily) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->contextily) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib->contextily) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->contextily) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: click>=3.0 in /opt/conda/lib/python3.11/site-packages (from mercantile->contextily) (8.1.6)
# Requirement already satisfied: affine in /opt/conda/lib/python3.11/site-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.11/site-packages (from rasterio->contextily) (23.1.0)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.11/site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from rasterio->contextily) (1.4.7)
# Requirement already satisfied: click-plugins in /opt/conda/lib/python3.11/site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from rasterio->contextily) (68.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import pandas as pd
import geopandas as gpd
import matplotlib as mpl
import folium
from folium import plugins
from matplotlib import pyplot as plt
import matplotlib.patheffects as pe
import mapclassify
from census import Census
import contextily as ctx 
from adjustText import adjust_text

plt.rcParams["figure.figsize"] = (10,10) # set this once for a default plot size

# %%
#Read my dataset
file_path = 'nuclear_power_plants.csv'
df = gpd.read_file(file_path)

# %%
df
# Out:
#       Id                  Name   Latitude   Longitude Country CountryCode  \
# 0      1                Ågesta  59.206000   18.082900  Sweden          SE
# 1      2  Akademik Lomonosov-1  69.709579  170.306250  Russia          RU
# 2      3  Akademik Lomonosov-2  69.709579  170.306250  Russia          RU
# 3      4              Akhvaz-1                           Iran          IR
# 4      5              Akhvaz-2                           Iran          IR
# ..   ...                   ...        ...         ...     ...         ...
# 798  815          BREST-OD-300  56.637414   84.904510  Russia          RU
# 799  816            Sanaocun-2  27.201487  120.517974   China          CN
# 800  817            El Dabaa-2  31.044167   28.497778   Egypt          EG
# 801  818            El Dabaa-3  31.044167   28.497778   Egypt          EG
# 802  819              Lufeng-5                          China          CN
#
#                  Status ReactorType        ReactorModel ConstructionStartAt  \
# 0              Shutdown        PHWR                              1957-12-01
# 1           Operational         PWR  KLT-40S 'Floating'          2007-04-15
# 2           Operational         PWR  KLT-40S 'Floating'          2007-04-15
# 3               Planned
# 4               Planned
# ..                  ...         ...                 ...                 ...
# 798  Under Construction         FBR        BREST-OD-300          2021-06-08
# 799  Under Construction         PWR             HRP1000          2021-12-30
# 800  Under Construction         PWR           VVER-1200          2022-11-19
# 801  Under Construction         PWR           VVER-1200          2023-05-03
# 802  Under Construction         PWR             HPR1000          2022-09-08
#
#     OperationalFrom OperationalTo Capacity              LastUpdatedAt  \
# 0        1964-05-01    1974-06-02        9  2015-05-24T04:51:37+03:00
# 1        2020-05-22                     30                 2021-05-31
# 2        2020-05-22                     30                 2021-05-31
# 3
# 4
# ..              ...           ...      ...                        ...
# 798                                    300  2022-01-05T00:04:08+02:00
# 799                                   1117  2022-04-21T20:26:19+03:00
# 800                                   1100  2023-08-28T08:01:45+03:00
# 801                                   1100  2023-08-28T08:24:00+03:00
# 802                                   1116  2023-08-28T08:01:45+03:00
#
#                    Source IAEAId geometry
# 0                WNA/IAEA    528     None
# 1    WNA/IAEA/Google Maps    895     None
# 2    WNA/IAEA/Google Maps    896     None
# 3                     WNA            None
# 4                     WNA            None
# ..                    ...    ...      ...
# 798              IAEA/WNA   1106     None
# 799                  IAEA   1107     None
# 800        IAEA/Wikipedia    138     None
# 801        IAEA/Wikipedia   1120     None
# 802                  IAEA   1113     None
#
# [803 rows x 17 columns]

# %%
df = df[df['Country'] == 'United States']
df
# Out:
#       Id                            Name   Latitude   Longitude  \
# 16    17  Arkansas Nuclear One-1 (ANO-1)  35.310000  -93.230000
# 17    18  Arkansas Nuclear One-2 (ANO-2)  35.310000  -93.229000
# 37    38                 Beaver Valley-1  40.624000  -80.432000
# 38    39                 Beaver Valley-2  40.624000  -80.432000
# 56    57                  Big Rock Point  45.359000  -85.195000
# ..   ...                             ...        ...         ...
# 727  737                     Watts Bar-2  35.601000  -84.789000
# 730  740                      Wolf Creek  38.239000  -95.691000
# 754  764                     Yankee Rowe  42.728000  -72.929000
# 762  778                          Zion-1  42.446000  -87.801000
# 763  779                          Zion-2  42.446000  -87.801000
#
#            Country CountryCode       Status ReactorType      ReactorModel  \
# 16   United States          US  Operational         PWR  B&W LLP (DRYAMB)
# 17   United States          US  Operational         PWR   CE 2LP (DRYAMB)
# 37   United States          US  Operational         PWR   WH 3LP (DRYSUB)
# 38   United States          US  Operational         PWR   WH 3LP (DRYSUB)
# 56   United States          US     Shutdown         BWR
# ..             ...         ...          ...         ...               ...
# 727  United States          US  Operational         PWR   WH 4LP (ICECND)
# 730  United States          US  Operational         PWR   WH 4LP (DRYAMB)
# 754  United States          US     Shutdown         PWR               PWR
# 762  United States          US     Shutdown         PWR            WH 4LP
# 763  United States          US     Shutdown         PWR            WH 4LP
#
#     ConstructionStartAt OperationalFrom OperationalTo Capacity  \
# 16           1968-10-01      1974-12-19                    850
# 17           1968-12-06      1980-03-26                    912
# 37           1970-06-26      1976-10-01                    835
# 38           1974-05-03      1987-11-17                    836
# 56           1960-05-01      1963-03-29    1997-08-29       72
# ..                  ...             ...           ...      ...
# 727          1973-09-01      2016-10-19                   1165
# 730          1977-05-31      1985-09-03                   1170
# 754          1957-11-01      1961-07-01    1991-10-01      175
# 762          1968-12-01      1973-12-31    1998-02-13     1040
# 763          1968-12-01      1974-09-17    1998-02-13     1040
#
#                  LastUpdatedAt    Source IAEAId geometry
# 16   2017-02-10T23:58:30+02:00  WNA/IAEA    652     None
# 17   2017-02-10T23:58:53+02:00  WNA/IAEA    689     None
# 37   2017-02-10T23:58:44+02:00  WNA/IAEA    669     None
# 38   2017-02-10T23:58:59+02:00  WNA/IAEA    712     None
# 56   2015-05-24T04:51:41+03:00  WNA/IAEA    601     None
# ..                         ...       ...    ...      ...
# 727  2017-02-10T23:58:57+02:00  WNA/IAEA    700     None
# 730  2017-02-10T23:59:19+02:00  WNA/IAEA    751     None
# 754  2015-05-24T04:51:43+03:00  WNA/IAEA    638     None
# 762  2017-02-10T23:58:20+02:00  WNA/IAEA    640     None
# 763  2017-02-10T23:58:24+02:00  WNA/IAEA    646     None
#
# [137 rows x 17 columns]

# %%
df['Capacity'] = df['Capacity'].replace('', '0').astype(int)

# %%
df['Latitude'] = df['Latitude'].replace('', '0.0').astype(float)

# %%
df['Longitude'] = df['Longitude'].replace('', '0.0').astype(float)

# %%
df = df.loc[(df['Latitude'] != 0.0) & (df['Longitude'] != 0.0)]

# %%
df['Status'] = df['Status'].astype(str)

# %%
df['Country'] = df['Country'].astype(str)

# %%
df['Name'] = df['Name'].astype(str)

# %%
df.shape
# Out:
# (137, 17)

# %%
center = [37.0902, -95.7129]

# creating map
map = folium.Map(location = center, zoom_start = 4.2)
for i, j in df.iterrows():
    location = [j['Latitude'], j['Longitude']]
    folium.Marker(location, popup = f'Name: {j["Name"]}').add_to(map)
map.save('Distribution_map.html')

# %%
import folium

# Assuming 'Status', 'Capacity', and 'ReactorType' are columns in your DataFrame df
# Add a 'layer' column to distinguish between operational and non-operational
df['layer'] = df['Status'].apply(lambda x: 'Operational' if x == 'Operational' else 'Non-Operational')

# Define the center coordinates for the United States
center_us = [37.0902, -95.7129]

# Create a base map with the new center coordinates
map = folium.Map(location=center_us, zoom_start=4)

# Create layers for operational, non-operational, low capacity, high capacity, and reactor type labels
operational_layer = folium.FeatureGroup(name='Operational')
non_operational_layer = folium.FeatureGroup(name='Non-Operational')
low_capacity_layer = folium.FeatureGroup(name='Low Capacity')
high_capacity_layer = folium.FeatureGroup(name='High Capacity')
reactor_type_label_layer = folium.FeatureGroup(name='Reactor Type (Labels)')

# Add markers to the respective layers
for i, j in df.iterrows():
    location = [j['Latitude'], j['Longitude']]
    popup_text = f'Country: {j["Country"]}, Status: {j["Status"]}, Capacity: {j["Capacity"]}, Reactor Type: {j["ReactorType"]}'

    if j['Status'] == 'Operational':
        folium.Marker(location, popup=popup_text, icon=folium.Icon(color='green')).add_to(operational_layer)
    else:
        folium.Marker(location, popup=popup_text, icon=folium.Icon(color='red')).add_to(non_operational_layer)

    # Define colors for low and high capacity
    if j['Capacity'] < 50:
        folium.CircleMarker(location, radius=8, color='red', fill=True, fill_color='lightred', fill_opacity=0.7).add_to(low_capacity_layer)
    else:
        folium.CircleMarker(location, radius=8, color='Darkgreen', fill=True, fill_color='lightgreen', fill_opacity=0.7).add_to(high_capacity_layer)

    # Add reactor type labels
    label = folium.Marker(location, icon=folium.DivIcon(html=f'<div style="font-size: 10pt; color: black">{j["ReactorType"]}</div>'))
    label.add_to(reactor_type_label_layer)

# Add layers to the map
operational_layer.add_to(map)
non_operational_layer.add_to(map)
low_capacity_layer.add_to(map)
high_capacity_layer.add_to(map)
reactor_type_label_layer.add_to(map)

# Add layer control to toggle between layers
folium.LayerControl().add_to(map)

# Display the map
map.save('map_with_layers.html')

# %%
import plotly.express as px
import pandas as pd

df.dropna(
    axis=0,
    how='any',
    thresh=None,
    subset=None,
    inplace=True
)

color_scale = [(0, 'orange'), (1,'red')]

fig = px.scatter_mapbox(df, 
                        lat="Latitude", 
                        lon="Longtitude", 
                        hover_name="Address", 
                        hover_data=["Address", "Listed"],
                        color="Listed",
                        color_continuous_scale=color_scale,
                        size="Listed",
                        zoom=8, 
                        height=800,
                        width=800)

fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_8997/2217175833.py in ?()
#       1 import plotly.express as px
#       2 import pandas as pd
#       3
# ----> 4 df.dropna(
#       5     axis=0,
#       6     how='any',
#       7     thresh=None,
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6379         1    Batman  Batmobile 1940-04-25
#    6380         2  Catwoman   Bullwhip        NaT
#    6381         """
#    6382         if (how is not no_default) and (thresh is not no_default):
# -> 6383             raise TypeError(
#    6384                 "You cannot set both the how and thresh arguments at the same time."
#    6385             )
#    6386
#
# TypeError: You cannot set both the how and thresh arguments at the same time.

# %%
c = Census("")
#Picking the state of NJ
nj_census = c.acs5.state_county_tract(fields = ('NAME', 'B01001_001E', 'B01001_001M', 'B19055_001E', 'B19055_001M','GEO_ID'),
                                      state_fips = '34', #I chose New York
                                      county_fips = "*", # an asterisk means all options; use it here to get all the counties within New York
                                      tract = "*", # get all the tracts within these counties
                                      year = 2019)
# Out:
# ---------------------------------------------------------------------------
# CensusException                           Traceback (most recent call last)
# Cell In[22], line 3
#       1 c = Census("")
#       2 #Picking the state of NJ
# ----> 3 nj_census = c.acs5.state_county_tract(fields = ('NAME', 'B01001_001E', 'B01001_001M', 'B19055_001E', 'B19055_001M','GEO_ID'),
#       4                                       state_fips = '*', #I chose New York
#       5                                       county_fips = "*", # an asterisk means all options; use it here to get all the counties within New York
#       6                                       tract = "*", # get all the tracts within these counties
#       7                                       year = 2019)
#
# File /opt/conda/lib/python3.11/site-packages/census/core.py:50, in supported_years.<locals>.inner.<locals>.wrapper(self, *args, **kwargs)
#      47 if int(year) not in _years:
#      48     raise UnsupportedYearException(
#      49         'Geography is not available in {}. Available years include {}'.format(year, _years))
# ---> 50 return func(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/census/core.py:334, in ACS5Client.state_county_tract(self, fields, state_fips, county_fips, tract, **kwargs)
#     331 @supported_years()
#     332 def state_county_tract(self, fields, state_fips,
#     333                        county_fips, tract, **kwargs):
# --> 334     return self.get(fields, geo={
#     335         'for': 'tract:{}'.format(tract),
#     336         'in': 'state:{} county:{}'.format(state_fips, county_fips),
#     337     }, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/census/core.py:313, in ACSClient.get(self, *args, **kwargs)
#     310 def get(self, *args, **kwargs):
#     311     self._switch_endpoints(kwargs.get('year', self.default_year))
# --> 313     return super(ACSClient, self).get(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/census/core.py:159, in Client.get(self, fields, geo, year, **kwargs)
#     156 sort_by_geoid = len(fields) > 49 and (not year or year > 2009)
#     157 all_results = (self.query(forty_nine_fields, geo, year, sort_by_geoid=sort_by_geoid, **kwargs)
#     158                for forty_nine_fields in chunks(fields, 49))
# --> 159 merged_results = [merge(result) for result in zip(*all_results)]
#     161 return merged_results
#
# File /opt/conda/lib/python3.11/site-packages/census/core.py:157, in <genexpr>(.0)
#     150 """
#     151 The API only accepts up to 50 fields on each query.
#     152 Chunk requests, and use the unique GEO_ID to match up the chunks
#     153 in case the responses are in different orders.
#     154 GEO_ID is not reliably present in pre-2010 requests.
#     155 """
#     156 sort_by_geoid = len(fields) > 49 and (not year or year > 2009)
# --> 157 all_results = (self.query(forty_nine_fields, geo, year, sort_by_geoid=sort_by_geoid, **kwargs)
#     158                for forty_nine_fields in chunks(fields, 49))
#     159 merged_results = [merge(result) for result in zip(*all_results)]
#     161 return merged_results
#
# File /opt/conda/lib/python3.11/site-packages/census/core.py:60, in retry_on_transient_error.<locals>.wrapper(self, *args, **kwargs)
#      58 for _ in range(max(self.retries - 1, 0)):
#      59     try:
# ---> 60         result = func(self, *args, **kwargs)
#      61     except CensusException as e:
#      62         if "There was an error while running your query.  We've logged the error and we'll correct it ASAP.  Sorry for the inconvenience." in str(e):
#
# File /opt/conda/lib/python3.11/site-packages/census/core.py:214, in Client.query(self, fields, geo, year, sort_by_geoid, **kwargs)
#     211     return []
#     213 else:
# --> 214     raise CensusException(resp.text)
#
# CensusException: error: wildcard not allowed for 'state' in geography heirarchy

# %%
nj_census
# Out:
# [{'NAME': 'Census Tract 5012.10, Gloucester County, New Jersey',
#   'B01001_001E': 3452.0,
#   'B01001_001M': 249.0,
#   'B19055_001E': 1159.0,
#   'B19055_001M': 57.0,
#   'GEO_ID': '1400000US34015501210',
#   'state': '34',
#   'county': '015',
#   'tract': '501210'},
#  {'NAME': 'Census Tract 5013.01, Gloucester County, New Jersey',
#   'B01001_001E': 3570.0,
#   'B01001_001M': 155.0,
#   'B19055_001E': 1384.0,
#   'B19055_001M': 69.0,
#   'GEO_ID': '1400000US34015501301',
#   'state': '34',
#   'county': '015',
#   'tract': '501301'},
#  {'NAME': 'Census Tract 5013.03, Gloucester County, New Jersey',
#   'B01001_001E': 2594.0,
#   'B01001_001M': 197.0,
#   'B19055_001E': 977.0,
#   'B19055_001M': 72.0,
#   'GEO_ID': '1400000US34015501303',
#   'state': '34',
#   'county': '015',
#   'tract': '501303'},
#  {'NAME': 'Census Tract 5019, Gloucester County, New Jersey',
#   'B01001_001E': 4135.0,
#   'B01001_001M': 21.0,
#   'B19055_001E': 1320.0,
#   'B19055_001M': 141.0,
#   'GEO_ID': '1400000US34015501900',
#   'state': '34',
#   'county': '015',
#   'tract': '501900'},
#  {'NAME': 'Census Tract 5003, Gloucester County, New Jersey',
#   'B01001_001E': 2959.0,
#   'B01001_001M': 25.0,
#   'B19055_001E': 1087.0,
#   'B19055_001M': 65.0,
#   'GEO_ID': '1400000US34015500300',
#   'state': '34',
#   'county': '015',
#   'tract': '500300'},
#  {'NAME': 'Census Tract 5009, Gloucester County, New Jersey',
#   'B01001_001E': 2986.0,
#   'B01001_001M': 20.0,
#   'B19055_001E': 1052.0,
#   'B19055_001M': 68.0,
#   'GEO_ID': '1400000US34015500900',
#   'state': '34',
#   'county': '015',
#   'tract': '500900'},
#  {'NAME': 'Census Tract 5012.05, Gloucester County, New Jersey',
#   'B01001_001E': 2806.0,
#   'B01001_001M': 159.0,
#   'B19055_001E': 981.0,
#   'B19055_001M': 56.0,
#   'GEO_ID': '1400000US34015501205',
#   'state': '34',
#   'county': '015',
#   'tract': '501205'},
#  {'NAME': 'Census Tract 5002.02, Gloucester County, New Jersey',
#   'B01001_001E': 4582.0,
#   'B01001_001M': 315.0,
#   'B19055_001E': 1619.0,
#   'B19055_001M': 107.0,
#   'GEO_ID': '1400000US34015500202',
#   'state': '34',
#   'county': '015',
#   'tract': '500202'},
#  {'NAME': 'Census Tract 5010.02, Gloucester County, New Jersey',
#   'B01001_001E': 4171.0,
#   'B01001_001M': 308.0,
#   'B19055_001E': 1820.0,
#   'B19055_001M': 143.0,
#   'GEO_ID': '1400000US34015501002',
#   'state': '34',
#   'county': '015',
#   'tract': '501002'},
#  {'NAME': 'Census Tract 5023, Gloucester County, New Jersey',
#   'B01001_001E': 2579.0,
#   'B01001_001M': 24.0,
#   'B19055_001E': 852.0,
#   'B19055_001M': 61.0,
#   'GEO_ID': '1400000US34015502300',
#   'state': '34',
#   'county': '015',
#   'tract': '502300'},
#  {'NAME': 'Census Tract 5004, Gloucester County, New Jersey',
#   'B01001_001E': 5904.0,
#   'B01001_001M': 16.0,
#   'B19055_001E': 2475.0,
#   'B19055_001M': 243.0,
#   'GEO_ID': '1400000US34015500400',
#   'state': '34',
#   'county': '015',
#   'tract': '500400'},
#  {'NAME': 'Census Tract 5008, Gloucester County, New Jersey',
#   'B01001_001E': 2259.0,
#   'B01001_001M': 71.0,
#   'B19055_001E': 766.0,
#   'B19055_001M': 39.0,
#   'GEO_ID': '1400000US34015500800',
#   'state': '34',
#   'county': '015',
#   'tract': '500800'},
#  {'NAME': 'Census Tract 5010.01, Gloucester County, New Jersey',
#   'B01001_001E': 2135.0,
#   'B01001_001M': 211.0,
#   'B19055_001E': 766.0,
#   'B19055_001M': 68.0,
#   'GEO_ID': '1400000US34015501001',
#   'state': '34',
#   'county': '015',
#   'tract': '501001'},
#  {'NAME': 'Census Tract 5010.03, Gloucester County, New Jersey',
#   'B01001_001E': 3555.0,
#   'B01001_001M': 271.0,
#   'B19055_001E': 1430.0,
#   'B19055_001M': 128.0,
#   'GEO_ID': '1400000US34015501003',
#   'state': '34',
#   'county': '015',
#   'tract': '501003'},
#  {'NAME': 'Census Tract 5011.02, Gloucester County, New Jersey',
#   'B01001_001E': 6504.0,
#   'B01001_001M': 448.0,
#   'B19055_001E': 2837.0,
#   'B19055_001M': 164.0,
#   'GEO_ID': '1400000US34015501102',
#   'state': '34',
#   'county': '015',
#   'tract': '501102'},
#  {'NAME': 'Census Tract 5012.02, Gloucester County, New Jersey',
#   'B01001_001E': 4717.0,
#   'B01001_001M': 219.0,
#   'B19055_001E': 1566.0,
#   'B19055_001M': 45.0,
#   'GEO_ID': '1400000US34015501202',
#   'state': '34',
#   'county': '015',
#   'tract': '501202'},
#  {'NAME': 'Census Tract 5012.03, Gloucester County, New Jersey',
#   'B01001_001E': 3044.0,
#   'B01001_001M': 339.0,
#   'B19055_001E': 1147.0,
#   'B19055_001M': 111.0,
#   'GEO_ID': '1400000US34015501203',
#   'state': '34',
#   'county': '015',
#   'tract': '501203'},
#  {'NAME': 'Census Tract 5012.08, Gloucester County, New Jersey',
#   'B01001_001E': 3866.0,
#   'B01001_001M': 213.0,
#   'B19055_001E': 1637.0,
#   'B19055_001M': 93.0,
#   'GEO_ID': '1400000US34015501208',
#   'state': '34',
#   'county': '015',
#   'tract': '501208'},
#  {'NAME': 'Census Tract 5022, Gloucester County, New Jersey',
#   'B01001_001E': 12549.0,
#   'B01001_001M': 36.0,
#   'B19055_001E': 3934.0,
#   'B19055_001M': 137.0,
#   'GEO_ID': '1400000US34015502200',
#   'state': '34',
#   'county': '015',
#   'tract': '502200'},
#  {'NAME': 'Census Tract 5024, Gloucester County, New Jersey',
#   'B01001_001E': 5924.0,
#   'B01001_001M': 28.0,
#   'B19055_001E': 2056.0,
#   'B19055_001M': 114.0,
#   'GEO_ID': '1400000US34015502400',
#   'state': '34',
#   'county': '015',
#   'tract': '502400'},
#  {'NAME': 'Census Tract 5016.04, Gloucester County, New Jersey',
#   'B01001_001E': 7333.0,
#   'B01001_001M': 516.0,
#   'B19055_001E': 2560.0,
#   'B19055_001M': 146.0,
#   'GEO_ID': '1400000US34015501604',
#   'state': '34',
#   'county': '015',
#   'tract': '501604'},
#  {'NAME': 'Census Tract 120, Atlantic County, New Jersey',
#   'B01001_001E': 4514.0,
#   'B01001_001M': 392.0,
#   'B19055_001E': 1581.0,
#   'B19055_001M': 130.0,
#   'GEO_ID': '1400000US34001012000',
#   'state': '34',
#   'county': '001',
#   'tract': '012000'},
#  {'NAME': 'Census Tract 113, Atlantic County, New Jersey',
#   'B01001_001E': 4356.0,
#   'B01001_001M': 44.0,
#   'B19055_001E': 1750.0,
#   'B19055_001M': 132.0,
#   'GEO_ID': '1400000US34001011300',
#   'state': '34',
#   'county': '001',
#   'tract': '011300'},
#  {'NAME': 'Census Tract 117.01, Atlantic County, New Jersey',
#   'B01001_001E': 9003.0,
#   'B01001_001M': 564.0,
#   'B19055_001E': 2767.0,
#   'B19055_001M': 200.0,
#   'GEO_ID': '1400000US34001011701',
#   'state': '34',
#   'county': '001',
#   'tract': '011701'},
#  {'NAME': 'Census Tract 118.02, Atlantic County, New Jersey',
#   'B01001_001E': 15860.0,
#   'B01001_001M': 782.0,
#   'B19055_001E': 4920.0,
#   'B19055_001M': 292.0,
#   'GEO_ID': '1400000US34001011802',
#   'state': '34',
#   'county': '001',
#   'tract': '011802'},
#  {'NAME': 'Census Tract 127.02, Atlantic County, New Jersey',
#   'B01001_001E': 1622.0,
#   'B01001_001M': 164.0,
#   'B19055_001E': 694.0,
#   'B19055_001M': 77.0,
#   'GEO_ID': '1400000US34001012702',
#   'state': '34',
#   'county': '001',
#   'tract': '012702'},
#  {'NAME': 'Census Tract 4, Atlantic County, New Jersey',
#   'B01001_001E': 3374.0,
#   'B01001_001M': 480.0,
#   'B19055_001E': 1420.0,
#   'B19055_001M': 165.0,
#   'GEO_ID': '1400000US34001000400',
#   'state': '34',
#   'county': '001',
#   'tract': '000400'},
#  {'NAME': 'Census Tract 19, Atlantic County, New Jersey',
#   'B01001_001E': 1406.0,
#   'B01001_001M': 213.0,
#   'B19055_001E': 767.0,
#   'B19055_001M': 89.0,
#   'GEO_ID': '1400000US34001001900',
#   'state': '34',
#   'county': '001',
#   'tract': '001900'},
#  {'NAME': 'Census Tract 106, Atlantic County, New Jersey',
#   'B01001_001E': 4100.0,
#   'B01001_001M': 29.0,
#   'B19055_001E': 1454.0,
#   'B19055_001M': 204.0,
#   'GEO_ID': '1400000US34001010600',
#   'state': '34',
#   'county': '001',
#   'tract': '010600'},
#  {'NAME': 'Census Tract 122, Atlantic County, New Jersey',
#   'B01001_001E': 5151.0,
#   'B01001_001M': 517.0,
#   'B19055_001E': 1834.0,
#   'B19055_001M': 134.0,
#   'GEO_ID': '1400000US34001012200',
#   'state': '34',
#   'county': '001',
#   'tract': '012200'},
#  {'NAME': 'Census Tract 11, Atlantic County, New Jersey',
#   'B01001_001E': 2091.0,
#   'B01001_001M': 422.0,
#   'B19055_001E': 956.0,
#   'B19055_001M': 108.0,
#   'GEO_ID': '1400000US34001001100',
#   'state': '34',
#   'county': '001',
#   'tract': '001100'},
#  {'NAME': 'Census Tract 23, Atlantic County, New Jersey',
#   'B01001_001E': 2323.0,
#   'B01001_001M': 406.0,
#   'B19055_001E': 755.0,
#   'B19055_001M': 98.0,
#   'GEO_ID': '1400000US34001002300',
#   'state': '34',
#   'county': '001',
#   'tract': '002300'},
#  {'NAME': 'Census Tract 24, Atlantic County, New Jersey',
#   'B01001_001E': 2508.0,
#   'B01001_001M': 492.0,
#   'B19055_001E': 1243.0,
#   'B19055_001M': 159.0,
#   'GEO_ID': '1400000US34001002400',
#   'state': '34',
#   'county': '001',
#   'tract': '002400'},
#  {'NAME': 'Census Tract 25, Atlantic County, New Jersey',
#   'B01001_001E': 4035.0,
#   'B01001_001M': 497.0,
#   'B19055_001E': 2041.0,
#   'B19055_001M': 187.0,
#   'GEO_ID': '1400000US34001002500',
#   'state': '34',
#   'county': '001',
#   'tract': '002500'},
#  {'NAME': 'Census Tract 101.01, Atlantic County, New Jersey',
#   'B01001_001E': 3261.0,
#   'B01001_001M': 332.0,
#   'B19055_001E': 1415.0,
#   'B19055_001M': 134.0,
#   'GEO_ID': '1400000US34001010101',
#   'state': '34',
#   'county': '001',
#   'tract': '010101'},
#  {'NAME': 'Census Tract 107, Atlantic County, New Jersey',
#   'B01001_001E': 5925.0,
#   'B01001_001M': 18.0,
#   'B19055_001E': 2282.0,
#   'B19055_001M': 122.0,
#   'GEO_ID': '1400000US34001010700',
#   'state': '34',
#   'county': '001',
#   'tract': '010700'},
#  {'NAME': 'Census Tract 341, Union County, New Jersey',
#   'B01001_001E': 3309.0,
#   'B01001_001M': 289.0,
#   'B19055_001E': 1286.0,
#   'B19055_001M': 92.0,
#   'GEO_ID': '1400000US34039034100',
#   'state': '34',
#   'county': '039',
#   'tract': '034100'},
#  {'NAME': 'Census Tract 313, Union County, New Jersey',
#   'B01001_001E': 7031.0,
#   'B01001_001M': 680.0,
#   'B19055_001E': 2059.0,
#   'B19055_001M': 131.0,
#   'GEO_ID': '1400000US34039031300',
#   'state': '34',
#   'county': '039',
#   'tract': '031300'},
#  {'NAME': 'Census Tract 306, Warren County, New Jersey',
#   'B01001_001E': 3706.0,
#   'B01001_001M': 291.0,
#   'B19055_001E': 1764.0,
#   'B19055_001M': 135.0,
#   'GEO_ID': '1400000US34041030600',
#   'state': '34',
#   'county': '041',
#   'tract': '030600'},
#  {'NAME': 'Census Tract 316.02, Warren County, New Jersey',
#   'B01001_001E': 2431.0,
#   'B01001_001M': 169.0,
#   'B19055_001E': 970.0,
#   'B19055_001M': 60.0,
#   'GEO_ID': '1400000US34041031602',
#   'state': '34',
#   'county': '041',
#   'tract': '031602'},
#  {'NAME': 'Census Tract 321.01, Warren County, New Jersey',
#   'B01001_001E': 3050.0,
#   'B01001_001M': 21.0,
#   'B19055_001E': 1089.0,
#   'B19055_001M': 55.0,
#   'GEO_ID': '1400000US34041032101',
#   'state': '34',
#   'county': '041',
#   'tract': '032101'},
#  {'NAME': 'Census Tract 323, Warren County, New Jersey',
#   'B01001_001E': 3208.0,
#   'B01001_001M': 21.0,
#   'B19055_001E': 1308.0,
#   'B19055_001M': 83.0,
#   'GEO_ID': '1400000US34041032300',
#   'state': '34',
#   'county': '041',
#   'tract': '032300'},
#  {'NAME': 'Census Tract 307, Warren County, New Jersey',
#   'B01001_001E': 4575.0,
#   'B01001_001M': 457.0,
#   'B19055_001E': 1709.0,
#   'B19055_001M': 149.0,
#   'GEO_ID': '1400000US34041030700',
#   'state': '34',
#   'county': '041',
#   'tract': '030700'},
#  {'NAME': 'Census Tract 314.01, Warren County, New Jersey',
#   'B01001_001E': 4702.0,
#   'B01001_001M': 201.0,
#   'B19055_001E': 1680.0,
#   'B19055_001M': 96.0,
#   'GEO_ID': '1400000US34041031401',
#   'state': '34',
#   'county': '041',
#   'tract': '031401'},
#  {'NAME': 'Census Tract 319, Warren County, New Jersey',
#   'B01001_001E': 6395.0,
#   'B01001_001M': 16.0,
#   'B19055_001E': 2451.0,
#   'B19055_001M': 161.0,
#   'GEO_ID': '1400000US34041031900',
#   'state': '34',
#   'county': '041',
#   'tract': '031900'},
#  {'NAME': 'Census Tract 176, Essex County, New Jersey',
#   'B01001_001E': 4880.0,
#   'B01001_001M': 337.0,
#   'B19055_001E': 1631.0,
#   'B19055_001M': 92.0,
#   'GEO_ID': '1400000US34013017600',
#   'state': '34',
#   'county': '013',
#   'tract': '017600'},
#  {'NAME': 'Census Tract 186, Essex County, New Jersey',
#   'B01001_001E': 4555.0,
#   'B01001_001M': 536.0,
#   'B19055_001E': 1497.0,
#   'B19055_001M': 108.0,
#   'GEO_ID': '1400000US34013018600',
#   'state': '34',
#   'county': '013',
#   'tract': '018600'},
#  {'NAME': 'Census Tract 112, Essex County, New Jersey',
#   'B01001_001E': 2952.0,
#   'B01001_001M': 425.0,
#   'B19055_001E': 1177.0,
#   'B19055_001M': 121.0,
#   'GEO_ID': '1400000US34013011200',
#   'state': '34',
#   'county': '013',
#   'tract': '011200'},
#  {'NAME': 'Census Tract 116, Essex County, New Jersey',
#   'B01001_001E': 3213.0,
#   'B01001_001M': 436.0,
#   'B19055_001E': 904.0,
#   'B19055_001M': 70.0,
#   'GEO_ID': '1400000US34013011600',
#   'state': '34',
#   'county': '013',
#   'tract': '011600'},
#  {'NAME': 'Census Tract 46, Essex County, New Jersey',
#   'B01001_001E': 2977.0,
#   'B01001_001M': 515.0,
#   'B19055_001E': 1198.0,
#   'B19055_001M': 113.0,
#   'GEO_ID': '1400000US34013004600',
#   'state': '34',
#   'county': '013',
#   'tract': '004600'},
#  {'NAME': 'Census Tract 48.02, Essex County, New Jersey',
#   'B01001_001E': 2670.0,
#   'B01001_001M': 451.0,
#   'B19055_001E': 1480.0,
#   'B19055_001M': 137.0,
#   'GEO_ID': '1400000US34013004802',
#   'state': '34',
#   'county': '013',
#   'tract': '004802'},
#  {'NAME': 'Census Tract 64, Essex County, New Jersey',
#   'B01001_001E': 1154.0,
#   'B01001_001M': 161.0,
#   'B19055_001E': 550.0,
#   'B19055_001M': 60.0,
#   'GEO_ID': '1400000US34013006400',
#   'state': '34',
#   'county': '013',
#   'tract': '006400'},
#  {'NAME': 'Census Tract 68, Essex County, New Jersey',
#   'B01001_001E': 5811.0,
#   'B01001_001M': 562.0,
#   'B19055_001E': 1884.0,
#   'B19055_001M': 118.0,
#   'GEO_ID': '1400000US34013006800',
#   'state': '34',
#   'county': '013',
#   'tract': '006800'},
#  {'NAME': 'Census Tract 4, Essex County, New Jersey',
#   'B01001_001E': 2104.0,
#   'B01001_001M': 316.0,
#   'B19055_001E': 808.0,
#   'B19055_001M': 73.0,
#   'GEO_ID': '1400000US34013000400',
#   'state': '34',
#   'county': '013',
#   'tract': '000400'},
#  {'NAME': 'Census Tract 22.01, Essex County, New Jersey',
#   'B01001_001E': 8704.0,
#   'B01001_001M': 1015.0,
#   'B19055_001E': 3070.0,
#   'B19055_001M': 263.0,
#   'GEO_ID': '1400000US34013002201',
#   'state': '34',
#   'county': '013',
#   'tract': '002201'},
#  {'NAME': 'Census Tract 49, Essex County, New Jersey',
#   'B01001_001E': 3276.0,
#   'B01001_001M': 449.0,
#   'B19055_001E': 1453.0,
#   'B19055_001M': 128.0,
#   'GEO_ID': '1400000US34013004900',
#   'state': '34',
#   'county': '013',
#   'tract': '004900'},
#  {'NAME': 'Census Tract 1754.02, Passaic County, New Jersey',
#   'B01001_001E': 4491.0,
#   'B01001_001M': 479.0,
#   'B19055_001E': 1303.0,
#   'B19055_001M': 86.0,
#   'GEO_ID': '1400000US34031175402',
#   'state': '34',
#   'county': '031',
#   'tract': '175402'},
#  {'NAME': 'Census Tract 1756.01, Passaic County, New Jersey',
#   'B01001_001E': 2517.0,
#   'B01001_001M': 265.0,
#   'B19055_001E': 576.0,
#   'B19055_001M': 46.0,
#   'GEO_ID': '1400000US34031175601',
#   'state': '34',
#   'county': '031',
#   'tract': '175601'},
#  {'NAME': 'Census Tract 1756.02, Passaic County, New Jersey',
#   'B01001_001E': 7673.0,
#   'B01001_001M': 827.0,
#   'B19055_001E': 2240.0,
#   'B19055_001M': 107.0,
#   'GEO_ID': '1400000US34031175602',
#   'state': '34',
#   'county': '031',
#   'tract': '175602'},
#  {'NAME': 'Census Tract 1757.01, Passaic County, New Jersey',
#   'B01001_001E': 5345.0,
#   'B01001_001M': 630.0,
#   'B19055_001E': 1580.0,
#   'B19055_001M': 104.0,
#   'GEO_ID': '1400000US34031175701',
#   'state': '34',
#   'county': '031',
#   'tract': '175701'},
#  {'NAME': 'Census Tract 1757.03, Passaic County, New Jersey',
#   'B01001_001E': 4336.0,
#   'B01001_001M': 435.0,
#   'B19055_001E': 1626.0,
#   'B19055_001M': 124.0,
#   'GEO_ID': '1400000US34031175703',
#   'state': '34',
#   'county': '031',
#   'tract': '175703'},
#  {'NAME': 'Census Tract 1757.04, Passaic County, New Jersey',
#   'B01001_001E': 4138.0,
#   'B01001_001M': 454.0,
#   'B19055_001E': 1284.0,
#   'B19055_001M': 90.0,
#   'GEO_ID': '1400000US34031175704',
#   'state': '34',
#   'county': '031',
#   'tract': '175704'},
#  {'NAME': 'Census Tract 1758.01, Passaic County, New Jersey',
#   'B01001_001E': 3832.0,
#   'B01001_001M': 356.0,
#   'B19055_001E': 1272.0,
#   'B19055_001M': 84.0,
#   'GEO_ID': '1400000US34031175801',
#   'state': '34',
#   'county': '031',
#   'tract': '175801'},
#  {'NAME': 'Census Tract 1758.02, Passaic County, New Jersey',
#   'B01001_001E': 6812.0,
#   'B01001_001M': 794.0,
#   'B19055_001E': 1697.0,
#   'B19055_001M': 111.0,
#   'GEO_ID': '1400000US34031175802',
#   'state': '34',
#   'county': '031',
#   'tract': '175802'},
#  {'NAME': 'Census Tract 1802.01, Passaic County, New Jersey',
#   'B01001_001E': 3874.0,
#   'B01001_001M': 451.0,
#   'B19055_001E': 1167.0,
#   'B19055_001M': 74.0,
#   'GEO_ID': '1400000US34031180201',
#   'state': '34',
#   'county': '031',
#   'tract': '180201'},
#  {'NAME': 'Census Tract 1802.02, Passaic County, New Jersey',
#   'B01001_001E': 7176.0,
#   'B01001_001M': 731.0,
#   'B19055_001E': 1797.0,
#   'B19055_001M': 108.0,
#   'GEO_ID': '1400000US34031180202',
#   'state': '34',
#   'county': '031',
#   'tract': '180202'},
#  {'NAME': 'Census Tract 1823.01, Passaic County, New Jersey',
#   'B01001_001E': 1544.0,
#   'B01001_001M': 208.0,
#   'B19055_001E': 476.0,
#   'B19055_001M': 37.0,
#   'GEO_ID': '1400000US34031182301',
#   'state': '34',
#   'county': '031',
#   'tract': '182301'},
#  {'NAME': 'Census Tract 1823.02, Passaic County, New Jersey',
#   'B01001_001E': 5973.0,
#   'B01001_001M': 732.0,
#   'B19055_001E': 1669.0,
#   'B19055_001M': 124.0,
#   'GEO_ID': '1400000US34031182302',
#   'state': '34',
#   'county': '031',
#   'tract': '182302'},
#  {'NAME': 'Census Tract 1831.01, Passaic County, New Jersey',
#   'B01001_001E': 3135.0,
#   'B01001_001M': 276.0,
#   'B19055_001E': 1000.0,
#   'B19055_001M': 66.0,
#   'GEO_ID': '1400000US34031183101',
#   'state': '34',
#   'county': '031',
#   'tract': '183101'},
#  {'NAME': 'Census Tract 1831.02, Passaic County, New Jersey',
#   'B01001_001E': 4876.0,
#   'B01001_001M': 551.0,
#   'B19055_001E': 1354.0,
#   'B19055_001M': 105.0,
#   'GEO_ID': '1400000US34031183102',
#   'state': '34',
#   'county': '031',
#   'tract': '183102'},
#  {'NAME': 'Census Tract 1964.01, Passaic County, New Jersey',
#   'B01001_001E': 4137.0,
#   'B01001_001M': 271.0,
#   'B19055_001E': 1251.0,
#   'B19055_001M': 93.0,
#   'GEO_ID': '1400000US34031196401',
#   'state': '34',
#   'county': '031',
#   'tract': '196401'},
#  {'NAME': 'Census Tract 1964.02, Passaic County, New Jersey',
#   'B01001_001E': 6892.0,
#   'B01001_001M': 272.0,
#   'B19055_001E': 2753.0,
#   'B19055_001M': 174.0,
#   'GEO_ID': '1400000US34031196402',
#   'state': '34',
#   'county': '031',
#   'tract': '196402'},
#  {'NAME': 'Census Tract 2167.01, Passaic County, New Jersey',
#   'B01001_001E': 6936.0,
#   'B01001_001M': 195.0,
#   'B19055_001E': 2225.0,
#   'B19055_001M': 100.0,
#   'GEO_ID': '1400000US34031216701',
#   'state': '34',
#   'county': '031',
#   'tract': '216701'},
#  {'NAME': 'Census Tract 2167.02, Passaic County, New Jersey',
#   'B01001_001E': 5315.0,
#   'B01001_001M': 198.0,
#   'B19055_001E': 1913.0,
#   'B19055_001M': 70.0,
#   'GEO_ID': '1400000US34031216702',
#   'state': '34',
#   'county': '031',
#   'tract': '216702'},
#  {'NAME': 'Census Tract 2238.01, Passaic County, New Jersey',
#   'B01001_001E': 3053.0,
#   'B01001_001M': 224.0,
#   'B19055_001E': 1062.0,
#   'B19055_001M': 53.0,
#   'GEO_ID': '1400000US34031223801',
#   'state': '34',
#   'county': '031',
#   'tract': '223801'},
#  {'NAME': 'Census Tract 2238.02, Passaic County, New Jersey',
#   'B01001_001E': 7567.0,
#   'B01001_001M': 214.0,
#   'B19055_001E': 2529.0,
#   'B19055_001M': 127.0,
#   'GEO_ID': '1400000US34031223802',
#   'state': '34',
#   'county': '031',
#   'tract': '223802'},
#  {'NAME': 'Census Tract 2366.01, Passaic County, New Jersey',
#   'B01001_001E': 4547.0,
#   'B01001_001M': 274.0,
#   'B19055_001E': 1487.0,
#   'B19055_001M': 92.0,
#   'GEO_ID': '1400000US34031236601',
#   'state': '34',
#   'county': '031',
#   'tract': '236601'},
#  {'NAME': 'Census Tract 2366.02, Passaic County, New Jersey',
#   'B01001_001E': 7162.0,
#   'B01001_001M': 269.0,
#   'B19055_001E': 2709.0,
#   'B19055_001M': 153.0,
#   'GEO_ID': '1400000US34031236602',
#   'state': '34',
#   'county': '031',
#   'tract': '236602'},
#  {'NAME': 'Census Tract 2641.01, Passaic County, New Jersey',
#   'B01001_001E': 6024.0,
#   'B01001_001M': 329.0,
#   'B19055_001E': 1741.0,
#   'B19055_001M': 126.0,
#   'GEO_ID': '1400000US34031264101',
#   'state': '34',
#   'county': '031',
#   'tract': '264101'},
#  {'NAME': 'Census Tract 2641.02, Passaic County, New Jersey',
#   'B01001_001E': 6523.0,
#   'B01001_001M': 327.0,
#   'B19055_001E': 2792.0,
#   'B19055_001M': 164.0,
#   'GEO_ID': '1400000US34031264102',
#   'state': '34',
#   'county': '031',
#   'tract': '264102'},
#  {'NAME': 'Census Tract 2642, Passaic County, New Jersey',
#   'B01001_001E': 4542.0,
#   'B01001_001M': 491.0,
#   'B19055_001E': 1474.0,
#   'B19055_001M': 104.0,
#   'GEO_ID': '1400000US34031264200',
#   'state': '34',
#   'county': '031',
#   'tract': '264200'},
#  {'NAME': 'Census Tract 529.04, Somerset County, New Jersey',
#   'B01001_001E': 2083.0,
#   'B01001_001M': 199.0,
#   'B19055_001E': 844.0,
#   'B19055_001M': 64.0,
#   'GEO_ID': '1400000US34035052904',
#   'state': '34',
#   'county': '035',
#   'tract': '052904'},
#  {'NAME': 'Census Tract 9900, Salem County, New Jersey',
#   'B01001_001E': 0.0,
#   'B01001_001M': 12.0,
#   'B19055_001E': 0.0,
#   'B19055_001M': 12.0,
#   'GEO_ID': '1400000US34033990000',
#   'state': '34',
#   'county': '033',
#   'tract': '990000'},
#  {'NAME': 'Census Tract 507.01, Somerset County, New Jersey',
#   'B01001_001E': 4181.0,
#   'B01001_001M': 296.0,
#   'B19055_001E': 1297.0,
#   'B19055_001M': 67.0,
#   'GEO_ID': '1400000US34035050701',
#   'state': '34',
#   'county': '035',
#   'tract': '050701'},
#  {'NAME': 'Census Tract 507.03, Somerset County, New Jersey',
#   'B01001_001E': 4846.0,
#   'B01001_001M': 274.0,
#   'B19055_001E': 1761.0,
#   'B19055_001M': 77.0,
#   'GEO_ID': '1400000US34035050703',
#   'state': '34',
#   'county': '035',
#   'tract': '050703'},
#  {'NAME': 'Census Tract 522.03, Somerset County, New Jersey',
#   'B01001_001E': 5307.0,
#   'B01001_001M': 228.0,
#   'B19055_001E': 1805.0,
#   'B19055_001M': 80.0,
#   'GEO_ID': '1400000US34035052203',
#   'state': '34',
#   'county': '035',
#   'tract': '052203'},
#  {'NAME': 'Census Tract 529.03, Somerset County, New Jersey',
#   'B01001_001E': 5962.0,
#   'B01001_001M': 189.0,
#   'B19055_001E': 3159.0,
#   'B19055_001M': 185.0,
#   'GEO_ID': '1400000US34035052903',
#   'state': '34',
#   'county': '035',
#   'tract': '052903'},
#  {'NAME': 'Census Tract 507.04, Somerset County, New Jersey',
#   'B01001_001E': 6771.0,
#   'B01001_001M': 364.0,
#   'B19055_001E': 2531.0,
#   'B19055_001M': 88.0,
#   'GEO_ID': '1400000US34035050704',
#   'state': '34',
#   'county': '035',
#   'tract': '050704'},
#  {'NAME': 'Census Tract 522.04, Somerset County, New Jersey',
#   'B01001_001E': 4916.0,
#   'B01001_001M': 243.0,
#   'B19055_001E': 1578.0,
#   'B19055_001M': 66.0,
#   'GEO_ID': '1400000US34035052204',
#   'state': '34',
#   'county': '035',
#   'tract': '052204'},
#  {'NAME': 'Census Tract 534.03, Somerset County, New Jersey',
#   'B01001_001E': 4529.0,
#   'B01001_001M': 420.0,
#   'B19055_001E': 2099.0,
#   'B19055_001M': 157.0,
#   'GEO_ID': '1400000US34035053403',
#   'state': '34',
#   'county': '035',
#   'tract': '053403'},
#  {'NAME': 'Census Tract 322.01, Bergen County, New Jersey',
#   'B01001_001E': 5750.0,
#   'B01001_001M': 306.0,
#   'B19055_001E': 2314.0,
#   'B19055_001M': 99.0,
#   'GEO_ID': '1400000US34003032201',
#   'state': '34',
#   'county': '003',
#   'tract': '032201'},
#  {'NAME': 'Census Tract 322.02, Bergen County, New Jersey',
#   'B01001_001E': 5098.0,
#   'B01001_001M': 379.0,
#   'B19055_001E': 2070.0,
#   'B19055_001M': 71.0,
#   'GEO_ID': '1400000US34003032202',
#   'state': '34',
#   'county': '003',
#   'tract': '032202'},
#  {'NAME': 'Census Tract 400.01, Bergen County, New Jersey',
#   'B01001_001E': 3543.0,
#   'B01001_001M': 142.0,
#   'B19055_001E': 1160.0,
#   'B19055_001M': 45.0,
#   'GEO_ID': '1400000US34003040001',
#   'state': '34',
#   'county': '003',
#   'tract': '040001'},
#  {'NAME': 'Census Tract 400.02, Bergen County, New Jersey',
#   'B01001_001E': 4598.0,
#   'B01001_001M': 141.0,
#   'B19055_001E': 1628.0,
#   'B19055_001M': 69.0,
#   'GEO_ID': '1400000US34003040002',
#   'state': '34',
#   'county': '003',
#   'tract': '040002'},
#  {'NAME': 'Census Tract 413.01, Bergen County, New Jersey',
#   'B01001_001E': 5805.0,
#   'B01001_001M': 408.0,
#   'B19055_001E': 1932.0,
#   'B19055_001M': 98.0,
#   'GEO_ID': '1400000US34003041301',
#   'state': '34',
#   'county': '003',
#   'tract': '041301'},
#  {'NAME': 'Census Tract 413.02, Bergen County, New Jersey',
#   'B01001_001E': 4086.0,
#   'B01001_001M': 348.0,
#   'B19055_001E': 1693.0,
#   'B19055_001M': 134.0,
#   'GEO_ID': '1400000US34003041302',
#   'state': '34',
#   'county': '003',
#   'tract': '041302'},
#  {'NAME': 'Census Tract 233.01, Bergen County, New Jersey',
#   'B01001_001E': 2750.0,
#   'B01001_001M': 224.0,
#   'B19055_001E': 1004.0,
#   'B19055_001M': 71.0,
#   'GEO_ID': '1400000US34003023301',
#   'state': '34',
#   'county': '003',
#   'tract': '023301'},
#  {'NAME': 'Census Tract 233.02, Bergen County, New Jersey',
#   'B01001_001E': 5267.0,
#   'B01001_001M': 595.0,
#   'B19055_001E': 2821.0,
#   'B19055_001M': 175.0,
#   'GEO_ID': '1400000US34003023302',
#   'state': '34',
#   'county': '003',
#   'tract': '023302'},
#  {'NAME': 'Census Tract 235.01, Bergen County, New Jersey',
#   'B01001_001E': 3710.0,
#   'B01001_001M': 466.0,
#   'B19055_001E': 1344.0,
#   'B19055_001M': 96.0,
#   'GEO_ID': '1400000US34003023501',
#   'state': '34',
#   'county': '003',
#   'tract': '023501'},
#  {'NAME': 'Census Tract 442.01, Bergen County, New Jersey',
#   'B01001_001E': 3790.0,
#   'B01001_001M': 200.0,
#   'B19055_001E': 1284.0,
#   'B19055_001M': 83.0,
#   'GEO_ID': '1400000US34003044201',
#   'state': '34',
#   'county': '003',
#   'tract': '044201'},
#  {'NAME': 'Census Tract 442.02, Bergen County, New Jersey',
#   'B01001_001E': 5135.0,
#   'B01001_001M': 450.0,
#   'B19055_001E': 2185.0,
#   'B19055_001M': 127.0,
#   'GEO_ID': '1400000US34003044202',
#   'state': '34',
#   'county': '003',
#   'tract': '044202'},
#  {'NAME': 'Census Tract 7004.07, Burlington County, New Jersey',
#   'B01001_001E': 4914.0,
#   'B01001_001M': 473.0,
#   'B19055_001E': 2778.0,
#   'B19055_001M': 179.0,
#   'GEO_ID': '1400000US34005700407',
#   'state': '34',
#   'county': '005',
#   'tract': '700407'},
#  {'NAME': 'Census Tract 7004.08, Burlington County, New Jersey',
#   'B01001_001E': 2229.0,
#   'B01001_001M': 248.0,
#   'B19055_001E': 1232.0,
#   'B19055_001M': 99.0,
#   'GEO_ID': '1400000US34005700408',
#   'state': '34',
#   'county': '005',
#   'tract': '700408'},
#  {'NAME': 'Census Tract 7022.09, Burlington County, New Jersey',
#   'B01001_001E': 3183.0,
#   'B01001_001M': 260.0,
#   'B19055_001E': 1106.0,
#   'B19055_001M': 82.0,
#   'GEO_ID': '1400000US34005702209',
#   'state': '34',
#   'county': '005',
#   'tract': '702209'},
#  {'NAME': 'Census Tract 7022.10, Burlington County, New Jersey',
#   'B01001_001E': 4744.0,
#   'B01001_001M': 303.0,
#   'B19055_001E': 1667.0,
#   'B19055_001M': 116.0,
#   'GEO_ID': '1400000US34005702210',
#   'state': '34',
#   'county': '005',
#   'tract': '702210'},
#  {'NAME': 'Census Tract 7029.13, Burlington County, New Jersey',
#   'B01001_001E': 4612.0,
#   'B01001_001M': 327.0,
#   'B19055_001E': 2462.0,
#   'B19055_001M': 112.0,
#   'GEO_ID': '1400000US34005702913',
#   'state': '34',
#   'county': '005',
#   'tract': '702913'},
#  {'NAME': 'Census Tract 7029.14, Burlington County, New Jersey',
#   'B01001_001E': 4174.0,
#   'B01001_001M': 276.0,
#   'B19055_001E': 1470.0,
#   'B19055_001M': 94.0,
#   'GEO_ID': '1400000US34005702914',
#   'state': '34',
#   'county': '005',
#   'tract': '702914'},
#  {'NAME': 'Census Tract 71, Essex County, New Jersey',
#   'B01001_001E': 4428.0,
#   'B01001_001M': 450.0,
#   'B19055_001E': 1355.0,
#   'B19055_001M': 80.0,
#   'GEO_ID': '1400000US34013007100',
#   'state': '34',
#   'county': '013',
#   'tract': '007100'},
#  {'NAME': 'Census Tract 74, Essex County, New Jersey',
#   'B01001_001E': 5388.0,
#   'B01001_001M': 453.0,
#   'B19055_001E': 928.0,
#   'B19055_001M': 63.0,
#   'GEO_ID': '1400000US34013007400',
#   'state': '34',
#   'county': '013',
#   'tract': '007400'},
#  {'NAME': 'Census Tract 76, Essex County, New Jersey',
#   'B01001_001E': 3508.0,
#   'B01001_001M': 449.0,
#   'B19055_001E': 1213.0,
#   'B19055_001M': 86.0,
#   'GEO_ID': '1400000US34013007600',
#   'state': '34',
#   'county': '013',
#   'tract': '007600'},
#  {'NAME': 'Census Tract 77, Essex County, New Jersey',
#   'B01001_001E': 2701.0,
#   'B01001_001M': 295.0,
#   'B19055_001E': 1055.0,
#   'B19055_001M': 59.0,
#   'GEO_ID': '1400000US34013007700',
#   'state': '34',
#   'county': '013',
#   'tract': '007700'},
#  {'NAME': 'Census Tract 92, Essex County, New Jersey',
#   'B01001_001E': 3062.0,
#   'B01001_001M': 539.0,
#   'B19055_001E': 1017.0,
#   'B19055_001M': 80.0,
#   'GEO_ID': '1400000US34013009200',
#   'state': '34',
#   'county': '013',
#   'tract': '009200'},
#  {'NAME': 'Census Tract 23, Essex County, New Jersey',
#   'B01001_001E': 4917.0,
#   'B01001_001M': 615.0,
#   'B19055_001E': 1624.0,
#   'B19055_001M': 119.0,
#   'GEO_ID': '1400000US34013002300',
#   'state': '34',
#   'county': '013',
#   'tract': '002300'},
#  {'NAME': 'Census Tract 66, Essex County, New Jersey',
#   'B01001_001E': 1481.0,
#   'B01001_001M': 186.0,
#   'B19055_001E': 721.0,
#   'B19055_001M': 47.0,
#   'GEO_ID': '1400000US34013006600',
#   'state': '34',
#   'county': '013',
#   'tract': '006600'},
#  {'NAME': 'Census Tract 52, Essex County, New Jersey',
#   'B01001_001E': 1307.0,
#   'B01001_001M': 282.0,
#   'B19055_001E': 427.0,
#   'B19055_001M': 64.0,
#   'GEO_ID': '1400000US34013005200',
#   'state': '34',
#   'county': '013',
#   'tract': '005200'},
#  {'NAME': 'Census Tract 181, Essex County, New Jersey',
#   'B01001_001E': 2057.0,
#   'B01001_001M': 292.0,
#   'B19055_001E': 796.0,
#   'B19055_001M': 60.0,
#   'GEO_ID': '1400000US34013018100',
#   'state': '34',
#   'county': '013',
#   'tract': '018100'},
#  {'NAME': 'Census Tract 11, Essex County, New Jersey',
#   'B01001_001E': 3154.0,
#   'B01001_001M': 486.0,
#   'B19055_001E': 595.0,
#   'B19055_001M': 56.0,
#   'GEO_ID': '1400000US34013001100',
#   'state': '34',
#   'county': '013',
#   'tract': '001100'},
#  {'NAME': 'Census Tract 14, Essex County, New Jersey',
#   'B01001_001E': 2816.0,
#   'B01001_001M': 408.0,
#   'B19055_001E': 984.0,
#   'B19055_001M': 82.0,
#   'GEO_ID': '1400000US34013001400',
#   'state': '34',
#   'county': '013',
#   'tract': '001400'},
#  {'NAME': 'Census Tract 206, Essex County, New Jersey',
#   'B01001_001E': 5088.0,
#   'B01001_001M': 261.0,
#   'B19055_001E': 1762.0,
#   'B19055_001M': 78.0,
#   'GEO_ID': '1400000US34013020600',
#   'state': '34',
#   'county': '013',
#   'tract': '020600'},
#  {'NAME': 'Census Tract 321.02, Warren County, New Jersey',
#   'B01001_001E': 5480.0,
#   'B01001_001M': 28.0,
#   'B19055_001E': 1893.0,
#   'B19055_001M': 88.0,
#   'GEO_ID': '1400000US34041032102',
#   'state': '34',
#   'county': '041',
#   'tract': '032102'},
#  {'NAME': 'Census Tract 324, Warren County, New Jersey',
#   'B01001_001E': 2082.0,
#   'B01001_001M': 159.0,
#   'B19055_001E': 917.0,
#   'B19055_001M': 63.0,
#   'GEO_ID': '1400000US34041032400',
#   'state': '34',
#   'county': '041',
#   'tract': '032400'},
#  {'NAME': 'Census Tract 308, Warren County, New Jersey',
#   'B01001_001E': 3083.0,
#   'B01001_001M': 220.0,
#   'B19055_001E': 1187.0,
#   'B19055_001M': 90.0,
#   'GEO_ID': '1400000US34041030800',
#   'state': '34',
#   'county': '041',
#   'tract': '030800'},
#  {'NAME': 'Census Tract 313.01, Warren County, New Jersey',
#   'B01001_001E': 5450.0,
#   'B01001_001M': 22.0,
#   'B19055_001E': 2112.0,
#   'B19055_001M': 181.0,
#   'GEO_ID': '1400000US34041031301',
#   'state': '34',
#   'county': '041',
#   'tract': '031301'},
#  {'NAME': 'Census Tract 320, Warren County, New Jersey',
#   'B01001_001E': 6490.0,
#   'B01001_001M': 18.0,
#   'B19055_001E': 2689.0,
#   'B19055_001M': 188.0,
#   'GEO_ID': '1400000US34041032000',
#   'state': '34',
#   'county': '041',
#   'tract': '032000'},
#  {'NAME': 'Census Tract 313.02, Warren County, New Jersey',
#   'B01001_001E': 4597.0,
#   'B01001_001M': 24.0,
#   'B19055_001E': 2196.0,
#   'B19055_001M': 116.0,
#   'GEO_ID': '1400000US34041031302',
#   'state': '34',
#   'county': '041',
#   'tract': '031302'},
#  {'NAME': 'Census Tract 322, Warren County, New Jersey',
#   'B01001_001E': 8295.0,
#   'B01001_001M': 17.0,
#   'B19055_001E': 3476.0,
#   'B19055_001M': 203.0,
#   'GEO_ID': '1400000US34041032200',
#   'state': '34',
#   'county': '041',
#   'tract': '032200'},
#  {'NAME': 'Census Tract 311.01, Warren County, New Jersey',
#   'B01001_001E': 5732.0,
#   'B01001_001M': 16.0,
#   'B19055_001E': 2159.0,
#   'B19055_001M': 122.0,
#   'GEO_ID': '1400000US34041031101',
#   'state': '34',
#   'county': '041',
#   'tract': '031101'},
#  {'NAME': 'Census Tract 309, Warren County, New Jersey',
#   'B01001_001E': 2980.0,
#   'B01001_001M': 322.0,
#   'B19055_001E': 1086.0,
#   'B19055_001M': 111.0,
#   'GEO_ID': '1400000US34041030900',
#   'state': '34',
#   'county': '041',
#   'tract': '030900'},
#  {'NAME': 'Census Tract 316.01, Warren County, New Jersey',
#   'B01001_001E': 4696.0,
#   'B01001_001M': 15.0,
#   'B19055_001E': 2073.0,
#   'B19055_001M': 138.0,
#   'GEO_ID': '1400000US34041031601',
#   'state': '34',
#   'county': '041',
#   'tract': '031601'},
#  {'NAME': 'Census Tract 317, Warren County, New Jersey',
#   'B01001_001E': 2590.0,
#   'B01001_001M': 32.0,
#   'B19055_001E': 981.0,
#   'B19055_001M': 83.0,
#   'GEO_ID': '1400000US34041031700',
#   'state': '34',
#   'county': '041',
#   'tract': '031700'},
#  {'NAME': 'Census Tract 314.02, Warren County, New Jersey',
#   'B01001_001E': 4783.0,
#   'B01001_001M': 203.0,
#   'B19055_001E': 1765.0,
#   'B19055_001M': 104.0,
#   'GEO_ID': '1400000US34041031402',
#   'state': '34',
#   'county': '041',
#   'tract': '031402'},
#  {'NAME': 'Census Tract 315, Warren County, New Jersey',
#   'B01001_001E': 7397.0,
#   'B01001_001M': 31.0,
#   'B19055_001E': 2935.0,
#   'B19055_001M': 183.0,
#   'GEO_ID': '1400000US34041031500',
#   'state': '34',
#   'county': '041',
#   'tract': '031500'},
#  {'NAME': 'Census Tract 318, Warren County, New Jersey',
#   'B01001_001E': 2737.0,
#   'B01001_001M': 152.0,
#   'B19055_001E': 996.0,
#   'B19055_001M': 65.0,
#   'GEO_ID': '1400000US34041031800',
#   'state': '34',
#   'county': '041',
#   'tract': '031800'},
#  {'NAME': 'Census Tract 311.02, Warren County, New Jersey',
#   'B01001_001E': 3891.0,
#   'B01001_001M': 203.0,
#   'B19055_001E': 1339.0,
#   'B19055_001M': 66.0,
#   'GEO_ID': '1400000US34041031102',
#   'state': '34',
#   'county': '041',
#   'tract': '031102'},
#  {'NAME': 'Census Tract 312, Warren County, New Jersey',
#   'B01001_001E': 7512.0,
#   'B01001_001M': 183.0,
#   'B19055_001E': 2812.0,
#   'B19055_001M': 159.0,
#   'GEO_ID': '1400000US34041031200',
#   'state': '34',
#   'county': '041',
#   'tract': '031200'},
#  {'NAME': 'Census Tract 162, Hudson County, New Jersey',
#   'B01001_001E': 4286.0,
#   'B01001_001M': 475.0,
#   'B19055_001E': 1574.0,
#   'B19055_001M': 115.0,
#   'GEO_ID': '1400000US34017016200',
#   'state': '34',
#   'county': '017',
#   'tract': '016200'},
#  {'NAME': 'Census Tract 164, Hudson County, New Jersey',
#   'B01001_001E': 3566.0,
#   'B01001_001M': 339.0,
#   'B19055_001E': 1419.0,
#   'B19055_001M': 124.0,
#   'GEO_ID': '1400000US34017016400',
#   'state': '34',
#   'county': '017',
#   'tract': '016400'},
#  {'NAME': 'Census Tract 179, Hudson County, New Jersey',
#   'B01001_001E': 3526.0,
#   'B01001_001M': 304.0,
#   'B19055_001E': 1730.0,
#   'B19055_001M': 126.0,
#   'GEO_ID': '1400000US34017017900',
#   'state': '34',
#   'county': '017',
#   'tract': '017900'},
#  {'NAME': 'Census Tract 181, Hudson County, New Jersey',
#   'B01001_001E': 2708.0,
#   'B01001_001M': 271.0,
#   'B19055_001E': 1241.0,
#   'B19055_001M': 91.0,
#   'GEO_ID': '1400000US34017018100',
#   'state': '34',
#   'county': '017',
#   'tract': '018100'},
#  {'NAME': 'Census Tract 192, Hudson County, New Jersey',
#   'B01001_001E': 3972.0,
#   'B01001_001M': 218.0,
#   'B19055_001E': 1934.0,
#   'B19055_001M': 109.0,
#   'GEO_ID': '1400000US34017019200',
#   'state': '34',
#   'county': '017',
#   'tract': '019200'},
#  {'NAME': 'Census Tract 160, Hudson County, New Jersey',
#   'B01001_001E': 3416.0,
#   'B01001_001M': 312.0,
#   'B19055_001E': 1215.0,
#   'B19055_001M': 95.0,
#   'GEO_ID': '1400000US34017016000',
#   'state': '34',
#   'county': '017',
#   'tract': '016000'},
#  {'NAME': 'Census Tract 149, Hudson County, New Jersey',
#   'B01001_001E': 3331.0,
#   'B01001_001M': 285.0,
#   'B19055_001E': 956.0,
#   'B19055_001M': 73.0,
#   'GEO_ID': '1400000US34017014900',
#   'state': '34',
#   'county': '017',
#   'tract': '014900'},
#  {'NAME': 'Census Tract 153, Hudson County, New Jersey',
#   'B01001_001E': 4010.0,
#   'B01001_001M': 445.0,
#   'B19055_001E': 1685.0,
#   'B19055_001M': 111.0,
#   'GEO_ID': '1400000US34017015300',
#   'state': '34',
#   'county': '017',
#   'tract': '015300'},
#  {'NAME': 'Census Tract 174, Hudson County, New Jersey',
#   'B01001_001E': 2489.0,
#   'B01001_001M': 261.0,
#   'B19055_001E': 954.0,
#   'B19055_001M': 65.0,
#   'GEO_ID': '1400000US34017017400',
#   'state': '34',
#   'county': '017',
#   'tract': '017400'},
#  {'NAME': 'Census Tract 186, Hudson County, New Jersey',
#   'B01001_001E': 2487.0,
#   'B01001_001M': 185.0,
#   'B19055_001E': 1238.0,
#   'B19055_001M': 58.0,
#   'GEO_ID': '1400000US34017018600',
#   'state': '34',
#   'county': '017',
#   'tract': '018600'},
#  {'NAME': 'Census Tract 189, Hudson County, New Jersey',
#   'B01001_001E': 3550.0,
#   'B01001_001M': 216.0,
#   'B19055_001E': 1807.0,
#   'B19055_001M': 112.0,
#   'GEO_ID': '1400000US34017018900',
#   'state': '34',
#   'county': '017',
#   'tract': '018900'},
#  {'NAME': 'Census Tract 62, Hudson County, New Jersey',
#   'B01001_001E': 3852.0,
#   'B01001_001M': 391.0,
#   'B19055_001E': 1483.0,
#   'B19055_001M': 92.0,
#   'GEO_ID': '1400000US34017006200',
#   'state': '34',
#   'county': '017',
#   'tract': '006200'},
#  {'NAME': 'Census Tract 526.01, Somerset County, New Jersey',
#   'B01001_001E': 9130.0,
#   'B01001_001M': 453.0,
#   'B19055_001E': 2934.0,
#   'B19055_001M': 177.0,
#   'GEO_ID': '1400000US34035052601',
#   'state': '34',
#   'county': '035',
#   'tract': '052601'},
#  {'NAME': 'Census Tract 529.01, Somerset County, New Jersey',
#   'B01001_001E': 860.0,
#   'B01001_001M': 67.0,
#   'B19055_001E': 325.0,
#   'B19055_001M': 29.0,
#   'GEO_ID': '1400000US34035052901',
#   'state': '34',
#   'county': '035',
#   'tract': '052901'},
#  {'NAME': 'Census Tract 532, Somerset County, New Jersey',
#   'B01001_001E': 7098.0,
#   'B01001_001M': 1088.0,
#   'B19055_001E': 2173.0,
#   'B19055_001M': 184.0,
#   'GEO_ID': '1400000US34035053200',
#   'state': '34',
#   'county': '035',
#   'tract': '053200'},
#  {'NAME': 'Census Tract 536.02, Somerset County, New Jersey',
#   'B01001_001E': 6091.0,
#   'B01001_001M': 229.0,
#   'B19055_001E': 2168.0,
#   'B19055_001M': 77.0,
#   'GEO_ID': '1400000US34035053602',
#   'state': '34',
#   'county': '035',
#   'tract': '053602'},
#  {'NAME': 'Census Tract 537.05, Somerset County, New Jersey',
#   'B01001_001E': 6050.0,
#   'B01001_001M': 347.0,
#   'B19055_001E': 2634.0,
#   'B19055_001M': 163.0,
#   'GEO_ID': '1400000US34035053705',
#   'state': '34',
#   'county': '035',
#   'tract': '053705'},
#  {'NAME': 'Census Tract 508.01, Somerset County, New Jersey',
#   'B01001_001E': 3841.0,
#   'B01001_001M': 208.0,
#   'B19055_001E': 1208.0,
#   'B19055_001M': 41.0,
#   'GEO_ID': '1400000US34035050801',
#   'state': '34',
#   'county': '035',
#   'tract': '050801'},
#  {'NAME': 'Census Tract 501, Somerset County, New Jersey',
#   'B01001_001E': 2651.0,
#   'B01001_001M': 305.0,
#   'B19055_001E': 1053.0,
#   'B19055_001M': 111.0,
#   'GEO_ID': '1400000US34035050100',
#   'state': '34',
#   'county': '035',
#   'tract': '050100'},
#  {'NAME': 'Census Tract 511, Somerset County, New Jersey',
#   'B01001_001E': 3193.0,
#   'B01001_001M': 441.0,
#   'B19055_001E': 1202.0,
#   'B19055_001M': 145.0,
#   'GEO_ID': '1400000US34035051100',
#   'state': '34',
#   'county': '035',
#   'tract': '051100'},
#  {'NAME': 'Census Tract 518, Somerset County, New Jersey',
#   'B01001_001E': 4074.0,
#   'B01001_001M': 389.0,
#   'B19055_001E': 1325.0,
#   'B19055_001M': 100.0,
#   'GEO_ID': '1400000US34035051800',
#   'state': '34',
#   'county': '035',
#   'tract': '051800'},
#  {'NAME': 'Census Tract 520.01, Somerset County, New Jersey',
#   'B01001_001E': 4049.0,
#   'B01001_001M': 507.0,
#   'B19055_001E': 1178.0,
#   'B19055_001M': 113.0,
#   'GEO_ID': '1400000US34035052001',
#   'state': '34',
#   'county': '035',
#   'tract': '052001'},
#  {'NAME': 'Census Tract 526.03, Somerset County, New Jersey',
#   'B01001_001E': 4093.0,
#   'B01001_001M': 299.0,
#   'B19055_001E': 2011.0,
#   'B19055_001M': 111.0,
#   'GEO_ID': '1400000US34035052603',
#   'state': '34',
#   'county': '035',
#   'tract': '052603'},
#  {'NAME': 'Census Tract 508.02, Somerset County, New Jersey',
#   'B01001_001E': 4387.0,
#   'B01001_001M': 236.0,
#   'B19055_001E': 1548.0,
#   'B19055_001M': 74.0,
#   'GEO_ID': '1400000US34035050802',
#   'state': '34',
#   'county': '035',
#   'tract': '050802'},
#  {'NAME': 'Census Tract 513, Somerset County, New Jersey',
#   'B01001_001E': 1939.0,
#   'B01001_001M': 269.0,
#   'B19055_001E': 702.0,
#   'B19055_001M': 83.0,
#   'GEO_ID': '1400000US34035051300',
#   'state': '34',
#   'county': '035',
#   'tract': '051300'},
#  {'NAME': 'Census Tract 515, Somerset County, New Jersey',
#   'B01001_001E': 3172.0,
#   'B01001_001M': 339.0,
#   'B19055_001E': 1188.0,
#   'B19055_001M': 110.0,
#   'GEO_ID': '1400000US34035051500',
#   'state': '34',
#   'county': '035',
#   'tract': '051500'},
#  {'NAME': 'Census Tract 521, Somerset County, New Jersey',
#   'B01001_001E': 7114.0,
#   'B01001_001M': 169.0,
#   'B19055_001E': 2174.0,
#   'B19055_001M': 131.0,
#   'GEO_ID': '1400000US34035052100',
#   'state': '34',
#   'county': '035',
#   'tract': '052100'},
#  {'NAME': 'Census Tract 528, Somerset County, New Jersey',
#   'B01001_001E': 2575.0,
#   'B01001_001M': 18.0,
#   'B19055_001E': 807.0,
#   'B19055_001M': 88.0,
#   'GEO_ID': '1400000US34035052800',
#   'state': '34',
#   'county': '035',
#   'tract': '052800'},
#  {'NAME': 'Census Tract 537.03, Somerset County, New Jersey',
#   'B01001_001E': 3546.0,
#   'B01001_001M': 292.0,
#   'B19055_001E': 1184.0,
#   'B19055_001M': 96.0,
#   'GEO_ID': '1400000US34035053703',
#   'state': '34',
#   'county': '035',
#   'tract': '053703'},
#  {'NAME': 'Census Tract 534.04, Somerset County, New Jersey',
#   'B01001_001E': 10682.0,
#   'B01001_001M': 855.0,
#   'B19055_001E': 3905.0,
#   'B19055_001M': 220.0,
#   'GEO_ID': '1400000US34035053404',
#   'state': '34',
#   'county': '035',
#   'tract': '053404'},
#  {'NAME': 'Census Tract 536.03, Somerset County, New Jersey',
#   'B01001_001E': 4872.0,
#   'B01001_001M': 232.0,
#   'B19055_001E': 1773.0,
#   'B19055_001M': 85.0,
#   'GEO_ID': '1400000US34035053603',
#   'state': '34',
#   'county': '035',
#   'tract': '053603'},
#  {'NAME': 'Census Tract 536.04, Somerset County, New Jersey',
#   'B01001_001E': 3517.0,
#   'B01001_001M': 190.0,
#   'B19055_001E': 1422.0,
#   'B19055_001M': 75.0,
#   'GEO_ID': '1400000US34035053604',
#   'state': '34',
#   'county': '035',
#   'tract': '053604'},
#  {'NAME': 'Census Tract 537.06, Somerset County, New Jersey',
#   'B01001_001E': 5114.0,
#   'B01001_001M': 359.0,
#   'B19055_001E': 1607.0,
#   'B19055_001M': 86.0,
#   'GEO_ID': '1400000US34035053706',
#   'state': '34',
#   'county': '035',
#   'tract': '053706'},
#  {'NAME': 'Census Tract 167, Hudson County, New Jersey',
#   'B01001_001E': 1590.0,
#   'B01001_001M': 138.0,
#   'B19055_001E': 632.0,
#   'B19055_001M': 48.0,
#   'GEO_ID': '1400000US34017016700',
#   'state': '34',
#   'county': '017',
#   'tract': '016700'},
#  {'NAME': 'Census Tract 170, Hudson County, New Jersey',
#   'B01001_001E': 5200.0,
#   'B01001_001M': 539.0,
#   'B19055_001E': 1823.0,
#   'B19055_001M': 108.0,
#   'GEO_ID': '1400000US34017017000',
#   'state': '34',
#   'county': '017',
#   'tract': '017000'},
#  {'NAME': 'Census Tract 185, Hudson County, New Jersey',
#   'B01001_001E': 6923.0,
#   'B01001_001M': 480.0,
#   'B19055_001E': 3123.0,
#   'B19055_001M': 143.0,
#   'GEO_ID': '1400000US34017018500',
#   'state': '34',
#   'county': '017',
#   'tract': '018500'},
#  {'NAME': 'Census Tract 16, Mercer County, New Jersey',
#   'B01001_001E': 1267.0,
#   'B01001_001M': 330.0,
#   'B19055_001E': 454.0,
#   'B19055_001M': 75.0,
#   'GEO_ID': '1400000US34021001600',
#   'state': '34',
#   'county': '021',
#   'tract': '001600'},
#  {'NAME': 'Census Tract 19, Mercer County, New Jersey',
#   'B01001_001E': 1609.0,
#   'B01001_001M': 295.0,
#   'B19055_001E': 418.0,
#   'B19055_001M': 49.0,
#   'GEO_ID': '1400000US34021001900',
#   'state': '34',
#   'county': '021',
#   'tract': '001900'},
#  {'NAME': 'Census Tract 26.01, Mercer County, New Jersey',
#   'B01001_001E': 4674.0,
#   'B01001_001M': 569.0,
#   'B19055_001E': 1372.0,
#   'B19055_001M': 92.0,
#   'GEO_ID': '1400000US34021002601',
#   'state': '34',
#   'county': '021',
#   'tract': '002601'},
#  {'NAME': 'Census Tract 39.03, Mercer County, New Jersey',
#   'B01001_001E': 2531.0,
#   'B01001_001M': 25.0,
#   'B19055_001E': 988.0,
#   'B19055_001M': 79.0,
#   'GEO_ID': '1400000US34021003903',
#   'state': '34',
#   'county': '021',
#   'tract': '003903'},
#  {'NAME': 'Census Tract 42.04, Mercer County, New Jersey',
#   'B01001_001E': 5209.0,
#   'B01001_001M': 550.0,
#   'B19055_001E': 1901.0,
#   'B19055_001M': 168.0,
#   'GEO_ID': '1400000US34021004204',
#   'state': '34',
#   'county': '021',
#   'tract': '004204'},
#  {'NAME': 'Census Tract 43.06, Mercer County, New Jersey',
#   'B01001_001E': 5618.0,
#   'B01001_001M': 384.0,
#   'B19055_001E': 1719.0,
#   'B19055_001M': 98.0,
#   'GEO_ID': '1400000US34021004306',
#   'state': '34',
#   'county': '021',
#   'tract': '004306'},
#  {'NAME': 'Census Tract 44.03, Mercer County, New Jersey',
#   'B01001_001E': 5375.0,
#   'B01001_001M': 24.0,
#   'B19055_001E': 1867.0,
#   'B19055_001M': 195.0,
#   'GEO_ID': '1400000US34021004403',
#   'state': '34',
#   'county': '021',
#   'tract': '004403'},
#  {'NAME': 'Census Tract 36.01, Mercer County, New Jersey',
#   'B01001_001E': 3660.0,
#   'B01001_001M': 512.0,
#   'B19055_001E': 1305.0,
#   'B19055_001M': 97.0,
#   'GEO_ID': '1400000US34021003601',
#   'state': '34',
#   'county': '021',
#   'tract': '003601'},
#  {'NAME': 'Census Tract 14.01, Mercer County, New Jersey',
#   'B01001_001E': 3666.0,
#   'B01001_001M': 453.0,
#   'B19055_001E': 1631.0,
#   'B19055_001M': 122.0,
#   'GEO_ID': '1400000US34021001401',
#   'state': '34',
#   'county': '021',
#   'tract': '001401'},
#  {'NAME': 'Census Tract 14.02, Mercer County, New Jersey',
#   'B01001_001E': 2053.0,
#   'B01001_001M': 338.0,
#   'B19055_001E': 603.0,
#   'B19055_001M': 77.0,
#   'GEO_ID': '1400000US34021001402',
#   'state': '34',
#   'county': '021',
#   'tract': '001402'},
#  {'NAME': 'Census Tract 30.03, Mercer County, New Jersey',
#   'B01001_001E': 6122.0,
#   'B01001_001M': 484.0,
#   'B19055_001E': 2402.0,
#   'B19055_001M': 130.0,
#   'GEO_ID': '1400000US34021003003',
#   'state': '34',
#   'county': '021',
#   'tract': '003003'},
#  {'NAME': 'Census Tract 1, Mercer County, New Jersey',
#   'B01001_001E': 3191.0,
#   'B01001_001M': 428.0,
#   'B19055_001E': 1145.0,
#   'B19055_001M': 105.0,
#   'GEO_ID': '1400000US34021000100',
#   'state': '34',
#   'county': '021',
#   'tract': '000100'},
#  {'NAME': 'Census Tract 3, Mercer County, New Jersey',
#   'B01001_001E': 4326.0,
#   'B01001_001M': 602.0,
#   'B19055_001E': 1257.0,
#   'B19055_001M': 123.0,
#   'GEO_ID': '1400000US34021000300',
#   'state': '34',
#   'county': '021',
#   'tract': '000300'},
#  {'NAME': 'Census Tract 4, Mercer County, New Jersey',
#   'B01001_001E': 4876.0,
#   'B01001_001M': 700.0,
#   'B19055_001E': 1415.0,
#   'B19055_001M': 121.0,
#   'GEO_ID': '1400000US34021000400',
#   'state': '34',
#   'county': '021',
#   'tract': '000400'},
#  {'NAME': 'Census Tract 110, Atlantic County, New Jersey',
#   'B01001_001E': 2447.0,
#   'B01001_001M': 247.0,
#   'B19055_001E': 833.0,
#   'B19055_001M': 74.0,
#   'GEO_ID': '1400000US34001011000',
#   'state': '34',
#   'county': '001',
#   'tract': '011000'},
#  {'NAME': 'Census Tract 112.01, Atlantic County, New Jersey',
#   'B01001_001E': 1697.0,
#   'B01001_001M': 151.0,
#   'B19055_001E': 588.0,
#   'B19055_001M': 55.0,
#   'GEO_ID': '1400000US34001011201',
#   'state': '34',
#   'county': '001',
#   'tract': '011201'},
#  {'NAME': 'Census Tract 123.02, Atlantic County, New Jersey',
#   'B01001_001E': 3419.0,
#   'B01001_001M': 153.0,
#   'B19055_001E': 1066.0,
#   'B19055_001M': 73.0,
#   'GEO_ID': '1400000US34001012302',
#   'state': '34',
#   'county': '001',
#   'tract': '012302'},
#  {'NAME': 'Census Tract 101.02, Atlantic County, New Jersey',
#   'B01001_001E': 1651.0,
#   'B01001_001M': 180.0,
#   'B19055_001E': 794.0,
#   'B19055_001M': 97.0,
#   'GEO_ID': '1400000US34001010102',
#   'state': '34',
#   'county': '001',
#   'tract': '010102'},
#  {'NAME': 'Census Tract 104.03, Atlantic County, New Jersey',
#   'B01001_001E': 7248.0,
#   'B01001_001M': 464.0,
#   'B19055_001E': 2197.0,
#   'B19055_001M': 136.0,
#   'GEO_ID': '1400000US34001010403',
#   'state': '34',
#   'county': '001',
#   'tract': '010403'},
#  {'NAME': 'Census Tract 109, Atlantic County, New Jersey',
#   'B01001_001E': 5596.0,
#   'B01001_001M': 362.0,
#   'B19055_001E': 2149.0,
#   'B19055_001M': 154.0,
#   'GEO_ID': '1400000US34001010900',
#   'state': '34',
#   'county': '001',
#   'tract': '010900'},
#  {'NAME': 'Census Tract 115, Atlantic County, New Jersey',
# ...
#   'B01001_001E': 3522.0,
#   'B01001_001M': 252.0,
#   'B19055_001E': 1107.0,
#   'B19055_001M': 77.0,
#   'GEO_ID': '1400000US34037373200',
#   'state': '34',
#   'county': '037',
#   'tract': '373200'},
#  {'NAME': 'Census Tract 3725, Sussex County, New Jersey',
#   'B01001_001E': 3152.0,
#   'B01001_001M': 189.0,
#   'B19055_001E': 1218.0,
#   'B19055_001M': 85.0,
#   'GEO_ID': '1400000US34037372500',
#   'state': '34',
#   'county': '037',
#   'tract': '372500'},
#  {'NAME': 'Census Tract 3748, Sussex County, New Jersey',
#   'B01001_001E': 4030.0,
#   'B01001_001M': 253.0,
#   'B19055_001E': 1619.0,
#   'B19055_001M': 101.0,
#   'GEO_ID': '1400000US34037374800',
#   'state': '34',
#   'county': '037',
#   'tract': '374800'},
#  {'NAME': 'Census Tract 3747, Sussex County, New Jersey',
#   'B01001_001E': 3762.0,
#   'B01001_001M': 274.0,
#   'B19055_001E': 1490.0,
#   'B19055_001M': 118.0,
#   'GEO_ID': '1400000US34037374700',
#   'state': '34',
#   'county': '037',
#   'tract': '374700'},
#  {'NAME': 'Census Tract 104.02, Cumberland County, New Jersey',
#   'B01001_001E': 1043.0,
#   'B01001_001M': 432.0,
#   'B19055_001E': 0.0,
#   'B19055_001M': 12.0,
#   'GEO_ID': '1400000US34011010402',
#   'state': '34',
#   'county': '011',
#   'tract': '010402'},
#  {'NAME': 'Census Tract 304, Cumberland County, New Jersey',
#   'B01001_001E': 8713.0,
#   'B01001_001M': 725.0,
#   'B19055_001E': 3390.0,
#   'B19055_001M': 211.0,
#   'GEO_ID': '1400000US34011030400',
#   'state': '34',
#   'county': '011',
#   'tract': '030400'},
#  {'NAME': 'Census Tract 101.01, Cumberland County, New Jersey',
#   'B01001_001E': 2514.0,
#   'B01001_001M': 297.0,
#   'B19055_001E': 963.0,
#   'B19055_001M': 128.0,
#   'GEO_ID': '1400000US34011010101',
#   'state': '34',
#   'county': '011',
#   'tract': '010101'},
#  {'NAME': 'Census Tract 101.03, Cumberland County, New Jersey',
#   'B01001_001E': 4970.0,
#   'B01001_001M': 595.0,
#   'B19055_001E': 0.0,
#   'B19055_001M': 12.0,
#   'GEO_ID': '1400000US34011010103',
#   'state': '34',
#   'county': '011',
#   'tract': '010103'},
#  {'NAME': 'Census Tract 408, Cumberland County, New Jersey',
#   'B01001_001E': 5101.0,
#   'B01001_001M': 380.0,
#   'B19055_001E': 1743.0,
#   'B19055_001M': 106.0,
#   'GEO_ID': '1400000US34011040800',
#   'state': '34',
#   'county': '011',
#   'tract': '040800'},
#  {'NAME': 'Census Tract 302, Cumberland County, New Jersey',
#   'B01001_001E': 3869.0,
#   'B01001_001M': 485.0,
#   'B19055_001E': 1651.0,
#   'B19055_001M': 204.0,
#   'GEO_ID': '1400000US34011030200',
#   'state': '34',
#   'county': '011',
#   'tract': '030200'},
#  {'NAME': 'Census Tract 303, Cumberland County, New Jersey',
#   'B01001_001E': 3777.0,
#   'B01001_001M': 508.0,
#   'B19055_001E': 1484.0,
#   'B19055_001M': 156.0,
#   'GEO_ID': '1400000US34011030300',
#   'state': '34',
#   'county': '011',
#   'tract': '030300'},
#  {'NAME': 'Census Tract 305.01, Cumberland County, New Jersey',
#   'B01001_001E': 6528.0,
#   'B01001_001M': 451.0,
#   'B19055_001E': 2388.0,
#   'B19055_001M': 140.0,
#   'GEO_ID': '1400000US34011030501',
#   'state': '34',
#   'county': '011',
#   'tract': '030501'},
#  {'NAME': 'Census Tract 449, Morris County, New Jersey',
#   'B01001_001E': 5656.0,
#   'B01001_001M': 393.0,
#   'B19055_001E': 1772.0,
#   'B19055_001M': 110.0,
#   'GEO_ID': '1400000US34027044900',
#   'state': '34',
#   'county': '027',
#   'tract': '044900'},
#  {'NAME': 'Census Tract 454.02, Morris County, New Jersey',
#   'B01001_001E': 5071.0,
#   'B01001_001M': 381.0,
#   'B19055_001E': 1767.0,
#   'B19055_001M': 116.0,
#   'GEO_ID': '1400000US34027045402',
#   'state': '34',
#   'county': '027',
#   'tract': '045402'},
#  {'NAME': 'Census Tract 457.01, Morris County, New Jersey',
#   'B01001_001E': 5883.0,
#   'B01001_001M': 274.0,
#   'B19055_001E': 2027.0,
#   'B19055_001M': 76.0,
#   'GEO_ID': '1400000US34027045701',
#   'state': '34',
#   'county': '027',
#   'tract': '045701'},
#  {'NAME': 'Census Tract 403, Morris County, New Jersey',
#   'B01001_001E': 8424.0,
#   'B01001_001M': 307.0,
#   'B19055_001E': 3747.0,
#   'B19055_001M': 165.0,
#   'GEO_ID': '1400000US34027040300',
#   'state': '34',
#   'county': '027',
#   'tract': '040300'},
#  {'NAME': 'Census Tract 407.01, Morris County, New Jersey',
#   'B01001_001E': 5864.0,
#   'B01001_001M': 220.0,
#   'B19055_001E': 1941.0,
#   'B19055_001M': 95.0,
#   'GEO_ID': '1400000US34027040701',
#   'state': '34',
#   'county': '027',
#   'tract': '040701'},
#  {'NAME': 'Census Tract 418.01, Morris County, New Jersey',
#   'B01001_001E': 2815.0,
#   'B01001_001M': 217.0,
#   'B19055_001E': 1110.0,
#   'B19055_001M': 37.0,
#   'GEO_ID': '1400000US34027041801',
#   'state': '34',
#   'county': '027',
#   'tract': '041801'},
#  {'NAME': 'Census Tract 531, Bergen County, New Jersey',
#   'B01001_001E': 3192.0,
#   'B01001_001M': 19.0,
#   'B19055_001E': 1232.0,
#   'B19055_001M': 80.0,
#   'GEO_ID': '1400000US34003053100',
#   'state': '34',
#   'county': '003',
#   'tract': '053100'},
#  {'NAME': 'Census Tract 542, Bergen County, New Jersey',
#   'B01001_001E': 4789.0,
#   'B01001_001M': 434.0,
#   'B19055_001E': 1709.0,
#   'B19055_001M': 95.0,
#   'GEO_ID': '1400000US34003054200',
#   'state': '34',
#   'county': '003',
#   'tract': '054200'},
#  {'NAME': 'Census Tract 551, Bergen County, New Jersey',
#   'B01001_001E': 6725.0,
#   'B01001_001M': 394.0,
#   'B19055_001E': 2193.0,
#   'B19055_001M': 123.0,
#   'GEO_ID': '1400000US34003055100',
#   'state': '34',
#   'county': '003',
#   'tract': '055100'},
#  {'NAME': 'Census Tract 612, Bergen County, New Jersey',
#   'B01001_001E': 3241.0,
#   'B01001_001M': 197.0,
#   'B19055_001E': 1183.0,
#   'B19055_001M': 65.0,
#   'GEO_ID': '1400000US34003061200',
#   'state': '34',
#   'county': '003',
#   'tract': '061200'},
#  {'NAME': 'Census Tract 562, Bergen County, New Jersey',
#   'B01001_001E': 4890.0,
#   'B01001_001M': 208.0,
#   'B19055_001E': 1870.0,
#   'B19055_001M': 87.0,
#   'GEO_ID': '1400000US34003056200',
#   'state': '34',
#   'county': '003',
#   'tract': '056200'},
#  {'NAME': 'Census Tract 463, Bergen County, New Jersey',
#   'B01001_001E': 4546.0,
#   'B01001_001M': 391.0,
#   'B19055_001E': 1698.0,
#   'B19055_001M': 106.0,
#   'GEO_ID': '1400000US34003046300',
#   'state': '34',
#   'county': '003',
#   'tract': '046300'},
#  {'NAME': 'Census Tract 521, Bergen County, New Jersey',
#   'B01001_001E': 7554.0,
#   'B01001_001M': 304.0,
#   'B19055_001E': 2805.0,
#   'B19055_001M': 114.0,
#   'GEO_ID': '1400000US34003052100',
#   'state': '34',
#   'county': '003',
#   'tract': '052100'},
#  {'NAME': 'Census Tract 543, Bergen County, New Jersey',
#   'B01001_001E': 6672.0,
#   'B01001_001M': 654.0,
#   'B19055_001E': 1857.0,
#   'B19055_001M': 116.0,
#   'GEO_ID': '1400000US34003054300',
#   'state': '34',
#   'county': '003',
#   'tract': '054300'},
#  {'NAME': 'Census Tract 591, Bergen County, New Jersey',
#   'B01001_001E': 5143.0,
#   'B01001_001M': 328.0,
#   'B19055_001E': 2047.0,
#   'B19055_001M': 133.0,
#   'GEO_ID': '1400000US34003059100',
#   'state': '34',
#   'county': '003',
#   'tract': '059100'},
#  {'NAME': 'Census Tract 600, Bergen County, New Jersey',
#   'B01001_001E': 8819.0,
#   'B01001_001M': 96.0,
#   'B19055_001E': 3331.0,
#   'B19055_001M': 162.0,
#   'GEO_ID': '1400000US34003060000',
#   'state': '34',
#   'county': '003',
#   'tract': '060000'},
#  {'NAME': 'Census Tract 34.01, Bergen County, New Jersey',
#   'B01001_001E': 2802.0,
#   'B01001_001M': 194.0,
#   'B19055_001E': 723.0,
#   'B19055_001M': 69.0,
#   'GEO_ID': '1400000US34003003401',
#   'state': '34',
#   'county': '003',
#   'tract': '003401'},
#  {'NAME': 'Census Tract 154, Bergen County, New Jersey',
#   'B01001_001E': 7180.0,
#   'B01001_001M': 759.0,
#   'B19055_001E': 2818.0,
#   'B19055_001M': 218.0,
#   'GEO_ID': '1400000US34003015400',
#   'state': '34',
#   'county': '003',
#   'tract': '015400'},
#  {'NAME': 'Census Tract 175, Bergen County, New Jersey',
#   'B01001_001E': 8395.0,
#   'B01001_001M': 518.0,
#   'B19055_001E': 2680.0,
#   'B19055_001M': 127.0,
#   'GEO_ID': '1400000US34003017500',
#   'state': '34',
#   'county': '003',
#   'tract': '017500'},
#  {'NAME': 'Census Tract 191.02, Bergen County, New Jersey',
#   'B01001_001E': 3150.0,
#   'B01001_001M': 236.0,
#   'B19055_001E': 1452.0,
#   'B19055_001M': 71.0,
#   'GEO_ID': '1400000US34003019102',
#   'state': '34',
#   'county': '003',
#   'tract': '019102'},
#  {'NAME': 'Census Tract 214, Bergen County, New Jersey',
#   'B01001_001E': 4932.0,
#   'B01001_001M': 475.0,
#   'B19055_001E': 1740.0,
#   'B19055_001M': 111.0,
#   'GEO_ID': '1400000US34003021400',
#   'state': '34',
#   'county': '003',
#   'tract': '021400'},
#  {'NAME': 'Census Tract 234.01, Bergen County, New Jersey',
#   'B01001_001E': 3796.0,
#   'B01001_001M': 348.0,
#   'B19055_001E': 1753.0,
#   'B19055_001M': 100.0,
#   'GEO_ID': '1400000US34003023401',
#   'state': '34',
#   'county': '003',
#   'tract': '023401'},
#  {'NAME': 'Census Tract 126.02, Atlantic County, New Jersey',
#   'B01001_001E': 1323.0,
#   'B01001_001M': 119.0,
#   'B19055_001E': 470.0,
#   'B19055_001M': 46.0,
#   'GEO_ID': '1400000US34001012602',
#   'state': '34',
#   'county': '001',
#   'tract': '012602'},
#  {'NAME': 'Census Tract 130, Atlantic County, New Jersey',
#   'B01001_001E': 3369.0,
#   'B01001_001M': 172.0,
#   'B19055_001E': 1512.0,
#   'B19055_001M': 115.0,
#   'GEO_ID': '1400000US34001013000',
#   'state': '34',
#   'county': '001',
#   'tract': '013000'},
#  {'NAME': 'Census Tract 3, Atlantic County, New Jersey',
#   'B01001_001E': 3765.0,
#   'B01001_001M': 350.0,
#   'B19055_001E': 1173.0,
#   'B19055_001M': 115.0,
#   'GEO_ID': '1400000US34001000300',
#   'state': '34',
#   'county': '001',
#   'tract': '000300'},
#  {'NAME': 'Census Tract 14, Atlantic County, New Jersey',
#   'B01001_001E': 3777.0,
#   'B01001_001M': 417.0,
#   'B19055_001E': 1504.0,
#   'B19055_001M': 103.0,
#   'GEO_ID': '1400000US34001001400',
#   'state': '34',
#   'county': '001',
#   'tract': '001400'},
#  {'NAME': 'Census Tract 8031, Monmouth County, New Jersey',
#   'B01001_001E': 3325.0,
#   'B01001_001M': 227.0,
#   'B19055_001E': 1303.0,
#   'B19055_001M': 99.0,
#   'GEO_ID': '1400000US34025803100',
#   'state': '34',
#   'county': '025',
#   'tract': '803100'},
#  {'NAME': 'Census Tract 8042, Monmouth County, New Jersey',
#   'B01001_001E': 5844.0,
#   'B01001_001M': 24.0,
#   'B19055_001E': 2043.0,
#   'B19055_001M': 95.0,
#   'GEO_ID': '1400000US34025804200',
#   'state': '34',
#   'county': '025',
#   'tract': '804200'},
#  {'NAME': 'Census Tract 8063, Monmouth County, New Jersey',
#   'B01001_001E': 2365.0,
#   'B01001_001M': 232.0,
#   'B19055_001E': 818.0,
#   'B19055_001M': 72.0,
#   'GEO_ID': '1400000US34025806300',
#   'state': '34',
#   'county': '025',
#   'tract': '806300'},
#  {'NAME': 'Census Tract 8077, Monmouth County, New Jersey',
#   'B01001_001E': 4192.0,
#   'B01001_001M': 336.0,
#   'B19055_001E': 1593.0,
#   'B19055_001M': 101.0,
#   'GEO_ID': '1400000US34025807700',
#   'state': '34',
#   'county': '025',
#   'tract': '807700'},
#  {'NAME': 'Census Tract 5021, Gloucester County, New Jersey',
#   'B01001_001E': 3148.0,
#   'B01001_001M': 21.0,
#   'B19055_001E': 987.0,
#   'B19055_001M': 60.0,
#   'GEO_ID': '1400000US34015502100',
#   'state': '34',
#   'county': '015',
#   'tract': '502100'},
#  {'NAME': 'Census Tract 5007.01, Gloucester County, New Jersey',
#   'B01001_001E': 7824.0,
#   'B01001_001M': 271.0,
#   'B19055_001E': 3061.0,
#   'B19055_001M': 154.0,
#   'GEO_ID': '1400000US34015500701',
#   'state': '34',
#   'county': '015',
#   'tract': '500701'},
#  {'NAME': 'Census Tract 5014.02, Gloucester County, New Jersey',
#   'B01001_001E': 3259.0,
#   'B01001_001M': 418.0,
#   'B19055_001E': 1007.0,
#   'B19055_001M': 124.0,
#   'GEO_ID': '1400000US34015501402',
#   'state': '34',
#   'county': '015',
#   'tract': '501402'},
#  {'NAME': 'Census Tract 5015, Gloucester County, New Jersey',
#   'B01001_001E': 8626.0,
#   'B01001_001M': 35.0,
#   'B19055_001E': 3029.0,
#   'B19055_001M': 267.0,
#   'GEO_ID': '1400000US34015501500',
#   'state': '34',
#   'county': '015',
#   'tract': '501500'},
#  {'NAME': 'Census Tract 5017.01, Gloucester County, New Jersey',
#   'B01001_001E': 5246.0,
#   'B01001_001M': 246.0,
#   'B19055_001E': 1838.0,
#   'B19055_001M': 78.0,
#   'GEO_ID': '1400000US34015501701',
#   'state': '34',
#   'county': '015',
#   'tract': '501701'},
#  {'NAME': 'Census Tract 262, Bergen County, New Jersey',
#   'B01001_001E': 5699.0,
#   'B01001_001M': 171.0,
#   'B19055_001E': 1908.0,
#   'B19055_001M': 67.0,
#   'GEO_ID': '1400000US34003026200',
#   'state': '34',
#   'county': '003',
#   'tract': '026200'},
#  {'NAME': 'Census Tract 313, Bergen County, New Jersey',
#   'B01001_001E': 5582.0,
#   'B01001_001M': 423.0,
#   'B19055_001E': 2114.0,
#   'B19055_001M': 141.0,
#   'GEO_ID': '1400000US34003031300',
#   'state': '34',
#   'county': '003',
#   'tract': '031300'},
#  {'NAME': 'Census Tract 371, Bergen County, New Jersey',
#   'B01001_001E': 5453.0,
#   'B01001_001M': 323.0,
#   'B19055_001E': 1726.0,
#   'B19055_001M': 98.0,
#   'GEO_ID': '1400000US34003037100',
#   'state': '34',
#   'county': '003',
#   'tract': '037100'},
#  {'NAME': 'Census Tract 381, Bergen County, New Jersey',
#   'B01001_001E': 5554.0,
#   'B01001_001M': 400.0,
#   'B19055_001E': 2352.0,
#   'B19055_001M': 115.0,
#   'GEO_ID': '1400000US34003038100',
#   'state': '34',
#   'county': '003',
#   'tract': '038100'},
#  {'NAME': 'Census Tract 391, Bergen County, New Jersey',
#   'B01001_001E': 4134.0,
#   'B01001_001M': 178.0,
#   'B19055_001E': 1456.0,
#   'B19055_001M': 68.0,
#   'GEO_ID': '1400000US34003039100',
#   'state': '34',
#   'county': '003',
#   'tract': '039100'},
#  {'NAME': 'Census Tract 472, Bergen County, New Jersey',
#   'B01001_001E': 4530.0,
#   'B01001_001M': 194.0,
#   'B19055_001E': 1440.0,
#   'B19055_001M': 45.0,
#   'GEO_ID': '1400000US34003047200',
#   'state': '34',
#   'county': '003',
#   'tract': '047200'},
#  {'NAME': 'Census Tract 545, Bergen County, New Jersey',
#   'B01001_001E': 4831.0,
#   'B01001_001M': 384.0,
#   'B19055_001E': 1517.0,
#   'B19055_001M': 89.0,
#   'GEO_ID': '1400000US34003054500',
#   'state': '34',
#   'county': '003',
#   'tract': '054500'},
#  {'NAME': 'Census Tract 614, Bergen County, New Jersey',
#   'B01001_001E': 5131.0,
#   'B01001_001M': 241.0,
#   'B19055_001E': 1733.0,
#   'B19055_001M': 72.0,
#   'GEO_ID': '1400000US34003061400',
#   'state': '34',
#   'county': '003',
#   'tract': '061400'},
#  {'NAME': 'Census Tract 474, Bergen County, New Jersey',
#   'B01001_001E': 4553.0,
#   'B01001_001M': 225.0,
#   'B19055_001E': 1839.0,
#   'B19055_001M': 100.0,
#   'GEO_ID': '1400000US34003047400',
#   'state': '34',
#   'county': '003',
#   'tract': '047400'},
#  {'NAME': 'Census Tract 372.02, Bergen County, New Jersey',
#   'B01001_001E': 7213.0,
#   'B01001_001M': 386.0,
#   'B19055_001E': 2863.0,
#   'B19055_001M': 131.0,
#   'GEO_ID': '1400000US34003037202',
#   'state': '34',
#   'county': '003',
#   'tract': '037202'},
#  {'NAME': 'Census Tract 79.12, Middlesex County, New Jersey',
#   'B01001_001E': 6948.0,
#   'B01001_001M': 485.0,
#   'B19055_001E': 2825.0,
#   'B19055_001M': 166.0,
#   'GEO_ID': '1400000US34023007912',
#   'state': '34',
#   'county': '023',
#   'tract': '007912'},
#  {'NAME': 'Census Tract 86.05, Middlesex County, New Jersey',
#   'B01001_001E': 2606.0,
#   'B01001_001M': 210.0,
#   'B19055_001E': 1093.0,
#   'B19055_001M': 72.0,
#   'GEO_ID': '1400000US34023008605',
#   'state': '34',
#   'county': '023',
#   'tract': '008605'},
#  {'NAME': 'Census Tract 88, Middlesex County, New Jersey',
#   'B01001_001E': 12341.0,
#   'B01001_001M': 845.0,
#   'B19055_001E': 660.0,
#   'B19055_001M': 61.0,
#   'GEO_ID': '1400000US34023008800',
#   'state': '34',
#   'county': '023',
#   'tract': '008800'},
#  {'NAME': 'Census Tract 90, Middlesex County, New Jersey',
#   'B01001_001E': 7199.0,
#   'B01001_001M': 759.0,
#   'B19055_001E': 1232.0,
#   'B19055_001M': 82.0,
#   'GEO_ID': '1400000US34023009000',
#   'state': '34',
#   'county': '023',
#   'tract': '009000'},
#  {'NAME': 'Census Tract 91, Middlesex County, New Jersey',
#   'B01001_001E': 3610.0,
#   'B01001_001M': 296.0,
#   'B19055_001E': 1233.0,
#   'B19055_001M': 76.0,
#   'GEO_ID': '1400000US34023009100',
#   'state': '34',
#   'county': '023',
#   'tract': '009100'},
#  {'NAME': 'Census Tract 92, Middlesex County, New Jersey',
#   'B01001_001E': 4355.0,
#   'B01001_001M': 379.0,
#   'B19055_001E': 1701.0,
#   'B19055_001M': 76.0,
#   'GEO_ID': '1400000US34023009200',
#   'state': '34',
#   'county': '023',
#   'tract': '009200'},
#  {'NAME': 'Census Tract 93, Middlesex County, New Jersey',
#   'B01001_001E': 5068.0,
#   'B01001_001M': 727.0,
#   'B19055_001E': 2203.0,
#   'B19055_001M': 171.0,
#   'GEO_ID': '1400000US34023009300',
#   'state': '34',
#   'county': '023',
#   'tract': '009300'},
#  ...]

# %%
# dataframe from the census data
nj_census_df = pd.DataFrame(nj_census)

# Show the dataframe first few 5 
nj_census_df.head()
# Out:
#                                                 NAME  B01001_001E  \
# 0  Census Tract 5012.10, Gloucester County, New J...       3452.0
# 1  Census Tract 5013.01, Gloucester County, New J...       3570.0
# 2  Census Tract 5013.03, Gloucester County, New J...       2594.0
# 3   Census Tract 5019, Gloucester County, New Jersey       4135.0
# 4   Census Tract 5003, Gloucester County, New Jersey       2959.0
#
#    B01001_001M  B19055_001E  B19055_001M                GEO_ID state county  \
# 0        249.0       1159.0         57.0  1400000US34015501210    34    015
# 1        155.0       1384.0         69.0  1400000US34015501301    34    015
# 2        197.0        977.0         72.0  1400000US34015501303    34    015
# 3         21.0       1320.0        141.0  1400000US34015501900    34    015
# 4         25.0       1087.0         65.0  1400000US34015500300    34    015
#
#     tract
# 0  501210
# 1  501301
# 2  501303
# 3  501900
# 4  500300

# %%
def remove_after_county(value):
    parts = value.split('County', 1)  # Split at the first occurrence of 'County'
    return 'County'.join(parts[:-1])  # Join all parts before the 'County'

# Apply the function to the 'Location' column
nj_census_df['NAME'] = nj_census_df['NAME'].apply(remove_after_county)

# %%
nj_census_df
# Out:
#                                    NAME  B01001_001E  B01001_001M  \
# 0     Census Tract 5012.10, Gloucester        3452.0        249.0
# 1     Census Tract 5013.01, Gloucester        3570.0        155.0
# 2     Census Tract 5013.03, Gloucester        2594.0        197.0
# 3        Census Tract 5019, Gloucester        4135.0         21.0
# 4        Census Tract 5003, Gloucester        2959.0         25.0
# ...                                 ...          ...          ...
# 2005       Census Tract 235.02, Bergen        5222.0        588.0
# 2006       Census Tract 236.01, Bergen        2868.0        355.0
# 2007       Census Tract 236.02, Bergen        4885.0        474.0
# 2008       Census Tract 321.03, Bergen        5154.0        372.0
# 2009       Census Tract 321.04, Bergen        4247.0        291.0
#
#       B19055_001E  B19055_001M                GEO_ID state county   tract
# 0          1159.0         57.0  1400000US34015501210    34    015  501210
# 1          1384.0         69.0  1400000US34015501301    34    015  501301
# 2           977.0         72.0  1400000US34015501303    34    015  501303
# 3          1320.0        141.0  1400000US34015501900    34    015  501900
# 4          1087.0         65.0  1400000US34015500300    34    015  500300
# ...           ...          ...                   ...   ...    ...     ...
# 2005       2225.0        140.0  1400000US34003023502    34    003  023502
# 2006       1278.0         92.0  1400000US34003023601    34    003  023601
# 2007       1420.0        111.0  1400000US34003023602    34    003  023602
# 2008       2488.0         86.0  1400000US34003032103    34    003  032103
# 2009        717.0         32.0  1400000US34003032104    34    003  032104
#
# [2010 rows x 9 columns]

# %%
def remove_before_comma(value):
    parts = value.split(',', 1)  # Split at the first occurrence of ','
    return parts[-1].strip()  # Take the part after ',' and remove leading/trailing spaces

# Apply the function to the 'Location' column
nj_census_df['NAME'] = nj_census_df['NAME'].apply(remove_before_comma)

# %%
nj_census_df
# Out:
#             NAME  B01001_001E  B01001_001M  B19055_001E  B19055_001M  \
# 0     Gloucester       3452.0        249.0       1159.0         57.0
# 1     Gloucester       3570.0        155.0       1384.0         69.0
# 2     Gloucester       2594.0        197.0        977.0         72.0
# 3     Gloucester       4135.0         21.0       1320.0        141.0
# 4     Gloucester       2959.0         25.0       1087.0         65.0
# ...          ...          ...          ...          ...          ...
# 2005      Bergen       5222.0        588.0       2225.0        140.0
# 2006      Bergen       2868.0        355.0       1278.0         92.0
# 2007      Bergen       4885.0        474.0       1420.0        111.0
# 2008      Bergen       5154.0        372.0       2488.0         86.0
# 2009      Bergen       4247.0        291.0        717.0         32.0
#
#                     GEO_ID state county   tract
# 0     1400000US34015501210    34    015  501210
# 1     1400000US34015501301    34    015  501301
# 2     1400000US34015501303    34    015  501303
# 3     1400000US34015501900    34    015  501900
# 4     1400000US34015500300    34    015  500300
# ...                    ...   ...    ...     ...
# 2005  1400000US34003023502    34    003  023502
# 2006  1400000US34003023601    34    003  023601
# 2007  1400000US34003023602    34    003  023602
# 2008  1400000US34003032103    34    003  032103
# 2009  1400000US34003032104    34    003  032104
#
# [2010 rows x 9 columns]

# %%
nj_census_df["GEOID"] = nj_census_df["state"] + nj_census_df["county"] + nj_census_df["tract"]

# delete the state and tract columns from the dataframe
nj_census_df = nj_census_df.drop(columns = ["state", "tract", "county"])

# %%
url_wv = 'https://www2.census.gov/geo/tiger/TIGER2019/TRACT/tl_2019_34_tract.zip'
map_data = gpd.read_file(url_wv)
# Out:
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# File /opt/conda/lib/python3.11/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File /opt/conda/lib/python3.11/http/client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File /opt/conda/lib/python3.11/http/client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /opt/conda/lib/python3.11/http/client.py:1281, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1280     raise CannotSendHeader()
# -> 1281 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /opt/conda/lib/python3.11/http/client.py:1041, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1040 del self._buffer[:]
# -> 1041 self.send(msg)
#    1043 if message_body is not None:
#    1044
#    1045     # create a consistent interface to message_body
#
# File /opt/conda/lib/python3.11/http/client.py:979, in HTTPConnection.send(self, data)
#     978 if self.auto_open:
# --> 979     self.connect()
#     980 else:
#
# File /opt/conda/lib/python3.11/http/client.py:1458, in HTTPSConnection.connect(self)
#    1456     server_hostname = self.host
# -> 1458 self.sock = self._context.wrap_socket(self.sock,
#    1459                                       server_hostname=server_hostname)
#
# File /opt/conda/lib/python3.11/ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File /opt/conda/lib/python3.11/ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#
# File /opt/conda/lib/python3.11/ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#
# SSLEOFError: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[21], line 2
#       1 url_wv = 'https://www2.census.gov/geo/tiger/TIGER2019/TRACT/tl_2019_34_tract.zip'
# ----> 2 map_data = gpd.read_file(url_wv)
#
# File /opt/conda/lib/python3.11/site-packages/geopandas/io/file.py:281, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     275 from_bytes = False
#     276 if _is_url(filename):
#     277     # if it is a url that supports random access -> pass through to
#     278     # pyogrio/fiona as is (to support downloading only part of the file)
#     279     # otherwise still download manually because pyogrio/fiona don't support
#     280     # all types of urls (https://github.com/geopandas/geopandas/issues/2908)
# --> 281     with urllib.request.urlopen(filename) as response:
#     282         if not response.headers.get("Accept-Ranges") == "bytes":
#     283             filename = response.read()
#
# File /opt/conda/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /opt/conda/lib/python3.11/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File /opt/conda/lib/python3.11/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File /opt/conda/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /opt/conda/lib/python3.11/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File /opt/conda/lib/python3.11/urllib/request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002)>

# %%
map_data
